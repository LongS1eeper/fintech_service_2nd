# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

# %%
data = pd.read_csv('./data/wine_train.csv')

# %%
data
# Out:
#      와인_종류  알코올_도수  사과산_함량  재_함량  재의_알칼리도  마그네슘_함량  총_페놀_함량  플라보노이드_함량  \
# 0        1   13.76    1.53  2.70     19.5      132     2.95       2.74
# 1        2   12.67    0.98  2.24     18.0       99     2.20       1.94
# 2        1   13.58    1.66  2.36     19.1      106     2.86       3.19
# 3        2   13.86    1.51  2.67     25.0       86     2.95       2.86
# 4        1   13.05    2.05  3.22     25.0      124     2.63       2.68
# ..     ...     ...     ...   ...      ...      ...      ...        ...
# 101      2   12.43    1.53  2.29     21.5       86     2.74       3.15
# 102      3   12.20    3.03  2.32     19.0       96     1.25       0.49
# 103      1   13.51    1.80  2.65     19.0      110     2.35       2.53
# 104      2   12.70    3.87  2.40     23.0      101     2.83       2.55
# 105      2   12.51    1.73  1.98     20.5       85     2.20       1.92
#
#      비플라보노이드_페놀_함량  프로안토시아닌_함량  색_강도    색조  희석_와인의_투과율_OD280_OD315  프롤린_함량
# 0             0.50        1.35  5.40  1.25                    3.00    1235
# 1             0.30        1.46  2.62  1.23                    3.16     450
# 2             0.22        1.95  6.90  1.09                    2.88    1515
# 3             0.21        1.87  3.38  1.36                    3.16     410
# 4             0.47        1.92  3.58  1.13                    3.20     830
# ..             ...         ...   ...   ...                     ...     ...
# 101           0.39        1.77  3.94  0.69                    2.84     352
# 102           0.40        0.73  5.50  0.66                    1.83     510
# 103           0.29        1.54  4.20  1.10                    2.87    1095
# 104           0.43        1.95  2.57  1.19                    3.13     463
# 105           0.32        1.48  2.94  1.04                    3.57     672
#
# [106 rows x 14 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   와인_종류                   106 non-null    int64
#  1   알코올_도수                  106 non-null    float64
#  2   사과산_함량                  106 non-null    float64
#  3   재_함량                    106 non-null    float64
#  4   재의_알칼리도                 106 non-null    float64
#  5   마그네슘_함량                 106 non-null    int64
#  6   총_페놀_함량                 106 non-null    float64
#  7   플라보노이드_함량               106 non-null    float64
#  8   비플라보노이드_페놀_함량           106 non-null    float64
#  9   프로안토시아닌_함량              106 non-null    float64
#  10  색_강도                    106 non-null    float64
#  11  색조                      106 non-null    float64
#  12  희석_와인의_투과율_OD280_OD315  106 non-null    float64
#  13  프롤린_함량                  106 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 11.7 KB

# %%
data['와인_종류'].value_counts()
# Out:
# 와인_종류
# 2    42
# 1    35
# 3    29
# Name: count, dtype: int64

# %%
data.columns
# Out:
# Index(['와인_종류', '알코올_도수', '사과산_함량', '재_함량', '재의_알칼리도', '마그네슘_함량', '총_페놀_함량',
#        '플라보노이드_함량', '비플라보노이드_페놀_함량', '프로안토시아닌_함량', '색_강도', '색조',
#        '희석_와인의_투과율_OD280_OD315', '프롤린_함량'],
#       dtype='object')

# %%
sns.boxplot(data.iloc[:,0:4])
# Out:
# <Axes: >

# %%
sns.boxplot(data.iloc[:,5])
# Out:
# <Axes: ylabel='마그네슘_함량'>

# %%
sns.boxplot(data.iloc[:,6:-1])
# Out:
# <Axes: >

# %% [markdown]
# 따로 정리할 데이터가 없으므로 바로 진행

# %%
X = data.drop('와인_종류', axis=1)
y = data['와인_종류']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mms = MinMaxScaler()
X_train_temp = mms.fit_transform(X_train)
X_test_temp = mms.transform(X_test)
mms_X_train = pd.DataFrame(X_train_temp, columns=X_train.columns, index=X_train.index)
mms_X_test = pd.DataFrame(X_test_temp, columns=X_test.columns, index=X_test.index)

# %% [markdown]
# ## mms 변수에 있는 MinMaxScaler 가중치 저장
# * 훈련을 도와주는 함수를 저장하는 느낌

# %% [markdown]
# ## joblib
# * joblib.dump(data, 경로, 파일명)
# * joblib.load(경로, 파일명)

# %%
import joblib

# %%
joblib.dump(mms, "./model/MinMax_info.joblib")
# Out:
# ['./model/MinMax_info.joblib']

# %%
mms_X_train
# Out:
#       알코올_도수    사과산_함량      재_함량   재의_알칼리도   마그네슘_함량   총_페놀_함량  플라보노이드_함량  \
# 79  0.700000  0.479508  0.634409  0.573171  0.294872  0.223077   0.021875
# 54  0.297368  0.141393  0.510753  0.743902  0.076923  0.203846   0.375000
# 98  0.755263  0.155738  0.408602  0.329268  0.217949  0.711538   0.906250
# 20  0.207895  0.163934  0.279570  0.542683  0.025641  0.480769   0.359375
# 92  0.823684  0.325820  0.602151  0.573171  0.089744  0.165385   0.065625
# ..       ...       ...       ...       ...       ...       ...        ...
# 43  0.744737  0.088115  0.489247  0.329268  0.179487  0.665385   0.831250
# 16  0.413158  0.086066  0.290323  0.481707  0.051282  0.076923   0.271875
# 59  0.484211  0.756148  0.602151  0.664634  0.025641  0.173077   0.050000
# 37  0.000000  0.120902  0.451613  0.664634  0.012821  0.465385   0.525000
# 33  0.621053  0.174180  0.677419  0.335366  0.115385  0.615385   0.765625
#
#     비플라보노이드_페놀_함량  프로안토시아닌_함량      색_강도        색조  희석_와인의_투과율_OD280_OD315  \
# 79           0.74    0.132867  0.392491  0.390244                0.189189
# 54           0.60    0.398601  0.099829  0.691057                0.359073
# 98           0.16    0.601399  0.411263  0.349593                0.772201
# 20           0.48    0.349650  0.066553  0.373984                0.428571
# 92           0.62    0.286713  0.718430  0.113821                0.146718
# ..            ...         ...       ...       ...                     ...
# 43           0.18    0.500000  0.506826  0.430894                0.857143
# 16           0.32    0.325175  0.099829  0.455285                0.555985
# 59           0.68    0.153846  0.543515  0.048780                0.204633
# 37           0.78    0.555944  0.052901  1.000000                0.594595
# 33           0.42    0.360140  0.300341  0.357724                0.729730
#
#       프롤린_함량
# 79  0.324980
# 54  0.175424
# 98  0.571544
# 20  0.110752
# 92  0.308812
# ..       ...
# 43  0.620049
# 16  0.229588
# 59  0.280517
# 37  0.104285
# 33  0.741310
#
# [74 rows x 13 columns]

# %%
y_train.value_counts()
# Out:
# 와인_종류
# 2    29
# 1    25
# 3    20
# Name: count, dtype: int64

# %%
y_train = pd.get_dummies(y_train)
y_train
# Out:
#         1      2      3
# 79  False  False   True
# 54  False   True  False
# 98   True  False  False
# 20  False   True  False
# 92  False  False   True
# ..    ...    ...    ...
# 43   True  False  False
# 16  False   True  False
# 59  False  False   True
# 37  False   True  False
# 33   True  False  False
#
# [74 rows x 3 columns]

# %%
y_test = pd.get_dummies(y_test)
y_test
# Out:
#          1      2      3
# 61   False  False   True
# 63   False   True  False
# 3    False   True  False
# 40   False   True  False
# 97   False  False   True
# 81   False  False   True
# 78   False  False   True
# 95   False   True  False
# 65   False  False   True
# 57    True  False  False
# 31   False  False   True
# 15   False  False   True
# 64    True  False  False
# 19   False   True  False
# 8    False   True  False
# 96   False   True  False
# 12   False   True  False
# 87   False  False   True
# 34   False   True  False
# 100  False   True  False
# 82    True  False  False
# 21   False   True  False
# 30    True  False  False
# 11    True  False  False
# 69   False  False   True
# 14    True  False  False
# 55    True  False  False
# 103   True  False  False
# 52    True  False  False
# 38    True  False  False
# 66   False   True  False
# 44   False   True  False

# %%
from keras.models import Sequential
from keras.layers import Input, Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
model = Sequential()
model.add(Input(shape=(mms_X_train.shape[1],)))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(y_train.shape[1], activation='softmax'))
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_7 (Dense)                 │ (None, 64)             │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 3)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,555 (13.89 KB)
#  Trainable params: 3,555 (13.89 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# 가장 효과가 좋은 모델을 wine_best_model로 저장

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

early_stop = EarlyStopping(patience=100)
# file_path = "./model/wine_{val_loss:.4f}_{epoch:04d}.keras" -> 매번 저장하는 코드
file_path = "./model/wine_best_model.keras"
model_save = ModelCheckpoint(filepath=file_path, save_best_only=True)

history = model.fit(mms_X_train, y_train,
                   epochs=1000,
                   batch_size=16,
                   validation_data=(mms_X_test, y_test),
                   callbacks=[early_stop, model_save])

plt.figure(figsize=(8,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel("epochs")
plt.ylabel("loss")
plt.legend(['train', 'test'])
plt.show()
# Out:
# Epoch 1/1000
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1747356115.772184  152640 service.cc:152] XLA service 0x7fe2f400b1f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1747356115.772254  152640 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce MX450, Compute Capability 7.5
# 2025-05-16 09:41:55.810962: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1747356116.104734  152640 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.1875 - loss: 1.2541
# I0000 00:00:1747356117.421160  152640 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 524ms/step - accuracy: 0.3338 - loss: 1.1612 - val_accuracy: 0.4062 - val_loss: 1.0588
# Epoch 2/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0
1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 6.9518e-04 - val_accuracy: 0.9688 - val_loss: 0.0889
# Epoch 181/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 8.3571e-04 - val_accuracy: 0.9688 - val_loss: 0.0889
# Epoch 182/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 6.8882e-04 - val_accuracy: 0.9688 - val_loss: 0.0888
# Epoch 183/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 7.6302e-04 - val_accuracy: 0.9688 - val_loss: 0.0888
# Epoch 184/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 7.4050e-04 - val_accuracy: 0.9688 - val_loss: 0.0894
# Epoch 185/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 7.3067e-04 - val_accuracy: 0.9688 - val_loss: 0.0894
# Epoch 186/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 6.7634e-04 - val_accuracy: 0.9688 - val_loss: 0.0901
# Epoch 187/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 6.7939e-04 - val_accuracy: 0.9688 - val_loss: 0.0901
# Epoch 188/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 8.7506e-04 - val_accuracy: 0.9688 - val_loss: 0.0905
# Epoch 189/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 5.3979e-04 - val_accuracy: 0.9688 - val_loss: 0.0910
# Epoch 190/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 5.8740e-04 - val_accuracy: 0.9688 - val_loss: 0.0925
# Epoch 191/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 6.9147e-04 - val_accuracy: 0.9688 - val_loss: 0.0920
# Epoch 192/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 6.4294e-04 - val_accuracy: 0.9688 - val_loss: 0.0919
# Epoch 193/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 6.6168e-04 - val_accuracy: 0.9688 - val_loss: 0.0929
# Epoch 194/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 5.2914e-04 - val_accuracy: 0.9688 - val_loss: 0.0925
# Epoch 195/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 6.3934e-04 - val_accuracy: 0.9688 - val_loss: 0.0920
# Epoch 196/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 6.0269e-04 - val_accuracy: 0.9688 - val_loss: 0.0912
# Epoch 197/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 6.8849e-04 - val_accuracy: 0.9688 - val_loss: 0.0915

# %% [markdown]
# # 머신러닝 스케일러와 모델 저장하기
# * 위쪽은 딥러닝, 아래는 랜덤포레스트

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

# %%
data = pd.read_csv("./data/wine_train.csv")
data
# Out:
#      와인_종류  알코올_도수  사과산_함량  재_함량  재의_알칼리도  마그네슘_함량  총_페놀_함량  플라보노이드_함량  \
# 0        1   13.76    1.53  2.70     19.5      132     2.95       2.74
# 1        2   12.67    0.98  2.24     18.0       99     2.20       1.94
# 2        1   13.58    1.66  2.36     19.1      106     2.86       3.19
# 3        2   13.86    1.51  2.67     25.0       86     2.95       2.86
# 4        1   13.05    2.05  3.22     25.0      124     2.63       2.68
# ..     ...     ...     ...   ...      ...      ...      ...        ...
# 101      2   12.43    1.53  2.29     21.5       86     2.74       3.15
# 102      3   12.20    3.03  2.32     19.0       96     1.25       0.49
# 103      1   13.51    1.80  2.65     19.0      110     2.35       2.53
# 104      2   12.70    3.87  2.40     23.0      101     2.83       2.55
# 105      2   12.51    1.73  1.98     20.5       85     2.20       1.92
#
#      비플라보노이드_페놀_함량  프로안토시아닌_함량  색_강도    색조  희석_와인의_투과율_OD280_OD315  프롤린_함량
# 0             0.50        1.35  5.40  1.25                    3.00    1235
# 1             0.30        1.46  2.62  1.23                    3.16     450
# 2             0.22        1.95  6.90  1.09                    2.88    1515
# 3             0.21        1.87  3.38  1.36                    3.16     410
# 4             0.47        1.92  3.58  1.13                    3.20     830
# ..             ...         ...   ...   ...                     ...     ...
# 101           0.39        1.77  3.94  0.69                    2.84     352
# 102           0.40        0.73  5.50  0.66                    1.83     510
# 103           0.29        1.54  4.20  1.10                    2.87    1095
# 104           0.43        1.95  2.57  1.19                    3.13     463
# 105           0.32        1.48  2.94  1.04                    3.57     672
#
# [106 rows x 14 columns]

# %%
data['와인_종류'].value_counts()
# Out:
# 와인_종류
# 2    42
# 1    35
# 3    29
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   와인_종류                   106 non-null    int64
#  1   알코올_도수                  106 non-null    float64
#  2   사과산_함량                  106 non-null    float64
#  3   재_함량                    106 non-null    float64
#  4   재의_알칼리도                 106 non-null    float64
#  5   마그네슘_함량                 106 non-null    int64
#  6   총_페놀_함량                 106 non-null    float64
#  7   플라보노이드_함량               106 non-null    float64
#  8   비플라보노이드_페놀_함량           106 non-null    float64
#  9   프로안토시아닌_함량              106 non-null    float64
#  10  색_강도                    106 non-null    float64
#  11  색조                      106 non-null    float64
#  12  희석_와인의_투과율_OD280_OD315  106 non-null    float64
#  13  프롤린_함량                  106 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 11.7 KB

# %%
sns.boxplot(data.iloc[:,6:-1])
# Out:
# <Axes: >

# %%
X = data.drop('와인_종류', axis=1)
y = data['와인_종류']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mms = MinMaxScaler()
X_train_temp = mms.fit_transform(X_train)
X_test_temp = mms.transform(X_test)
mms_X_train = pd.DataFrame(X_train_temp, columns=X_train.columns, index=X_train.index)
mms_X_test = pd.DataFrame(X_test_temp, columns=X_test.columns, index=X_test.index)

# %% [markdown]
# ## mms 변수에 있는 MinMaxScaler 가중치 저장

# %% [markdown]
# ## joblib
# * joblib.dump(data, 경로, 파일명)
# * joblib.load(경로, 파일명)

# %%
import joblib

# %%
# rfc할 때 mms 함수
joblib.dump(mms, "./model/MinMax_info2.joblib")
# Out:
# ['./model/MinMax_info2.joblib']

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
rfc = RandomForestClassifier(max_depth=3, n_estimators=500, n_jobs=-1, random_state=42)
rfc.fit(mms_X_train, y_train)
pred = rfc.predict(mms_X_test)
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        10
#            2       1.00      0.92      0.96        13
#            3       0.90      1.00      0.95         9
#
#     accuracy                           0.97        32
#    macro avg       0.97      0.97      0.97        32
# weighted avg       0.97      0.97      0.97        32

# %%
# 랜덤포레스트로 만든 모델 저장
joblib.dump(rfc, "./model/rfc_model.joblib")
# Out:
# ['./model/rfc_model.joblib']
