# %% [markdown]
# # 딥러닝 라이브러리 2가지
# ## 텐서플로우 (Google) - 산업용
# * 이미지 관련 라이브러리
# * keras를 이용해 코딩이 쉬움
# * 순차적, 함수적, 클래스
#
# ## 파이토치(meta) - 연구용
# * 자연어 관련 라이브러리
# * 허깅페이스, 랭체인
# * 클래스

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

# %%
data = pd.read_csv('https://raw.githubusercontent.com/haram4th/ablearn/main/Taitanic_train.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
data2 = pd.read_csv('https://raw.githubusercontent.com/haram4th/ablearn/main/Taitanic_train.csv')
data2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
data = data[['Survived','Pclass','Sex','Age','SibSp','Parch','Embarked']]

# %%
data['Family'] = data2['SibSp'] + data2['Parch']
# Out:
# /tmp/ipykernel_66602/280305035.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Family'] = data2['SibSp'] + data2['Parch']

# %%
data.head(2)
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch Embarked  Family
# 0         0       3    male  22.0      1      0        S       1
# 1         1       1  female  38.0      1      0        C       1

# %%
data['Age'] = data['Age'].fillna(data['Age'].mean())
data
# Out:
# /tmp/ipykernel_66602/3965396509.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Age'] = data['Age'].fillna(data['Age'].mean())
#      Survived  Pclass     Sex        Age  SibSp  Parch Embarked  Family
# 0           0       3    male  22.000000      1      0        S       1
# 1           1       1  female  38.000000      1      0        C       1
# 2           1       3  female  26.000000      0      0        S       0
# 3           1       1  female  35.000000      1      0        S       1
# 4           0       3    male  35.000000      0      0        S       0
# ..        ...     ...     ...        ...    ...    ...      ...     ...
# 886         0       2    male  27.000000      0      0        S       0
# 887         1       1  female  19.000000      0      0        S       0
# 888         0       3  female  29.699118      1      2        S       3
# 889         1       1    male  26.000000      0      0        C       0
# 890         0       3    male  32.000000      0      0        Q       0
#
# [891 rows x 8 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Embarked  889 non-null    object
#  7   Family    891 non-null    int64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 55.8+ KB

# %%
data['Embarked'] = data['Embarked'].fillna(data['Embarked'].mode()[0])
# Out:
# /tmp/ipykernel_66602/1825461941.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Embarked'] = data['Embarked'].fillna(data['Embarked'].mode()[0])

# %%
data = data.drop(['SibSp','Parch'], axis=1)
data
# Out:
#      Survived  Pclass     Sex        Age Embarked  Family
# 0           0       3    male  22.000000        S       1
# 1           1       1  female  38.000000        C       1
# 2           1       3  female  26.000000        S       0
# 3           1       1  female  35.000000        S       1
# 4           0       3    male  35.000000        S       0
# ..        ...     ...     ...        ...      ...     ...
# 886         0       2    male  27.000000        S       0
# 887         1       1  female  19.000000        S       0
# 888         0       3  female  29.699118        S       3
# 889         1       1    male  26.000000        C       0
# 890         0       3    male  32.000000        Q       0
#
# [891 rows x 6 columns]

# %%
data= pd.get_dummies(data, drop_first=True)
data
# Out:
#      Survived  Pclass        Age  Family  Sex_male  Embarked_Q  Embarked_S
# 0           0       3  22.000000       1      True       False        True
# 1           1       1  38.000000       1     False       False       False
# 2           1       3  26.000000       0     False       False        True
# 3           1       1  35.000000       1     False       False        True
# 4           0       3  35.000000       0      True       False        True
# ..        ...     ...        ...     ...       ...         ...         ...
# 886         0       2  27.000000       0      True       False        True
# 887         1       1  19.000000       0     False       False        True
# 888         0       3  29.699118       3     False       False        True
# 889         1       1  26.000000       0      True       False       False
# 890         0       3  32.000000       0      True        True       False
#
# [891 rows x 7 columns]

# %%
X = data.drop('Survived', axis=1)
y = data['Survived']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %% [markdown]
# # 딥러닝시에도 데이터의 스케일을 맞춰 주는 것이 좋다.
# * StandardScaler를 주로 사용, 이상값이 많을 경우 RobustScaler를 사용
# * 이진분류(0,1): MinMaxScaler
# * 연속값 예측; StandardScaler

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mms = MinMaxScaler()
mms_X_train = mms.fit_transform(X_train)
mms_X_test = mms.transform(X_test)
mms_X_train = pd.DataFrame(mms_X_train, columns=X_train.columns, index = X_train.index)
mms_X_test = pd.DataFrame(mms_X_test, columns=X_train.columns, index = X_test.index)
display(mms_X_train)
display(mms_X_test)
# Out:
#      Pclass       Age  Family  Sex_male  Embarked_Q  Embarked_S
# 748     0.0  0.233476     0.1       1.0         0.0         1.0
# 45      1.0  0.367921     0.0       1.0         0.0         1.0
# 28      1.0  0.367921     0.0       0.0         1.0         0.0
# 633     0.0  0.367921     0.0       1.0         0.0         1.0
# 403     1.0  0.346569     0.1       1.0         0.0         1.0
# ..      ...       ...     ...       ...         ...         ...
# 476     0.5  0.421965     0.1       1.0         0.0         1.0
# 190     0.5  0.396833     0.0       0.0         0.0         1.0
# 736     1.0  0.597889     0.4       0.0         0.0         1.0
# 462     0.0  0.585323     0.0       1.0         0.0         1.0
# 136     0.0  0.233476     0.2       0.0         0.0         1.0
#
# [623 rows x 6 columns]
#      Pclass       Age  Family  Sex_male  Embarked_Q  Embarked_S
# 625     0.0  0.761247     0.0       1.0         0.0         1.0
# 566     1.0  0.233476     0.0       1.0         0.0         1.0
# 459     1.0  0.367921     0.0       1.0         1.0         0.0
# 804     1.0  0.334004     0.0       1.0         0.0         1.0
# 338     1.0  0.560191     0.0       1.0         0.0         1.0
# ..      ...       ...     ...       ...         ...         ...
# 184     1.0  0.044986     0.2       0.0         0.0         1.0
# 607     0.0  0.334004     0.0       1.0         0.0         1.0
# 624     1.0  0.258608     0.0       1.0         0.0         1.0
# 103     1.0  0.409399     0.0       1.0         0.0         1.0
# 387     0.5  0.447097     0.0       0.0         0.0         1.0
#
# [268 rows x 6 columns]

# %% [markdown]
# # Tensorflow의 Sequential API를 사용한 순차적 모델 생성 및 분석
# * Sequential : 인공신경망을 순차적으로 작성할 때 사용
# * Dense: 층, 레이어
# * 1) 신경망 모델 정의
# * 2) 신경망 모델 훈련
# * 3) 훈련된 모델로 테스트
# * 4) 검증

# %%
import tensorflow as tf
from tensorflow.keras import Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
# Out:
# 2025-05-16 04:22:19.517200: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-16 04:22:19.535378: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747336939.553012   66602 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747336939.559766   66602 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1747336939.575867   66602 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747336939.575889   66602 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747336939.575891   66602 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747336939.575892   66602 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-16 04:22:19.581609: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# * 입력층은 반드시 독립변수의 수(input_dim)를 정확히 지정
# * 신경망 모델의 은닉층은 2~3개 정도로 한다.
# * Dense의 노드 수는 2의 거듭제곱 2 4 8 16 32
# * Dense의 노드는 큰 수에서 작은 수로 줄여나간다.
# * 은닉층의 활성화 함수: ReLu
# * 출력층은 이진분류일 경우 sigmoid, 다중분류일 경우 softmax
# * 회귀분석의 경우 (종속변수가 연속형(수치형)인 경우) 활성화 함수 없이 노드를 1로 지정

# %%
mms_X_train.shape
# Out:
# (623, 6)

# %%
# 신경망 모델 정의 keras 3.0, tensorflow 2.19 기준
model = Sequential()
model.add(Input(shape=(mms_X_train.shape[1],))) # 입력층
model.add(Dense(64, activation='relu'))  # 은닉층
model.add(Dense(32, activation='relu'))  # 은닉층
model.add(Dense(16, activation='relu'))  # 은닉층
model.add(Dense(1, activation='sigmoid')) # 출력층, 이진분류이므로 sigmoid
# Out:
# I0000 00:00:1747336942.675728   66602 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 560 MB memory:  -> device: 0, name: NVIDIA GeForce MX450, pci bus id: 0000:01:00.0, compute capability: 7.5

# %% [markdown]
# # 모델의 파라미터 세팅 model.compile()
# * loss : 오차 계산 지표
#     * 이진분류: binary_crossentropy
#     * 다중분류: categorical_crossentropy - y가 one-hot encoding
#     * 데이터에 0이 많은 희소행렬인 경우: sparse_categorical_crossentropy - y label encoding
#     * 연속형 데이터(회귀분석): mse
# * optimizer: learning_rate
#     * adam을 가장 많이 사용
# * metrics: 평가지표 accuracy

# %%
# 모델의 파라미터 세팅
model.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,073 (12.00 KB)
#  Trainable params: 3,073 (12.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
len(mms_X_train)
# Out:
# 623

# %% [markdown]
# # 모델 훈련 model.fit(X_train, y_train)
# * epochs: 전체 데이터를 한 번 훈련하는 주기 - 위의 경우에는 623개를 전부 훈련하는 주기
# * batch_size: 전체 데이터를 쪼개서 훈련, 데이터의 묶음, 메모리에 맞춰서 크기 조절(2의 배수) 32, 64로 쪼개서 넣는 것 추천
# * validation_data: 검증 데이터로 모델 검증 실시

# %%
history = model.fit(mms_X_train, y_train, epochs=100, batch_size=64, 
                    validation_data=(mms_X_test, y_test))
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1747336944.443452   70728 service.cc:152] XLA service 0x7fe53c00a980 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1747336944.443505   70728 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce MX450, Compute Capability 7.5
# 2025-05-16 04:22:24.476668: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8361 - loss: 0.3986 - val_accuracy: 0.8134 - val_loss: 0.4299
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8251 - loss: 0.4195 - val_accuracy: 0.8284 - val_loss: 0.4286
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8218 - loss: 0.4240 - val_accuracy: 0.8097 - val_loss: 0.4309
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8457 - loss: 0.3861 - val_accuracy: 0.8097 - val_loss: 0.4336
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8517 - loss: 0.3810 - val_accuracy: 0.8022 - val_loss: 0.4321

# %% [markdown]
# # 딥러닝 모델 성능 평가
# * 딥러닝에서 모델의 성능을 평가하는 지표는 loss
# * 보통 loss가 낮으면 accuracy가 올라가지만 비례하지 않을 때도 있음.
# * accuracy와 loss 간의 차이가 있을 때 loss가 낮은 모델이 우수한 모델

# %%
score = model.evaluate(mms_X_test, y_test)
print('test loss', score[0])
print('test accuracy', score[1])
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8105 - loss: 0.4339
# test loss 0.43208763003349304
# test accuracy 0.8022388219833374

# %%
for i in history.history:
    print(i)
# Out:
# accuracy
# loss
# val_accuracy
# val_loss

# %% [markdown]
# # 훈련 결과 시각화하기 history.history['loss'], history.history['val_loss']

# %%
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# # 모델의 예측 값 출력

# %%
pred = model.predict(mms_X_test)
pred
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# array([[0.21302748],
#        [0.15623157],
#        [0.11476091],
#        [0.11084142],
#        [0.05140772],
#        [0.28504387],
#        [0.13255292],
#        [0.83695185],
#        [0.09712512],
#        [0.9565923 ],
#        [0.8182171 ],
#        [0.992634  ],
#        [0.36118358],
#        [0.21238315],
#        [0.51323736],
#        [0.8362147 ],
#        [0.11476091],
#        [0.39102712],
#        [0.93572736],
#        [0.41347486],
#        [0.04375552],
#        [0.07960617],
#        [0.51830035],
#        [0.11084142],
#        [0.29912385],
#        [0.16981019],
#        [0.97049516],
#        [0.28106645],
#        [0.36728966],
#        [0.2159407 ],
#        [0.90408504],
#        [0.9718834 ],
#        [0.11476091],
#        [0.8251879 ],
#        [0.9882691 ],
#        [0.5186232 ],
#        [0.11476091],
#        [0.04728624],
#        [0.11476091],
#        [0.3215778 ],
#        [0.13255292],
#        [0.8806712 ],
#        [0.29976884],
#        [0.9863303 ],
#        [0.9852645 ],
#        [0.16588932],
#        [0.5336137 ],
#        [0.28674582],
#        [0.80706155],
#        [0.09842933],
#        [0.06022278],
#        [0.06924561],
#        [0.36118358],
#        [0.34814712],
#        [0.13746653],
#        [0.10361044],
#        [0.09842933],
#        [0.39658454],
#        [0.3038661 ],
#        [0.05669436],
#        [0.09842933],
#        [0.15623157],
#        [0.17094287],
#        [0.91334003],
#        [0.04742246],
#        [0.1664163 ],
#        [0.14339708],
#        [0.84957045],
#        [0.11832437],
#        [0.15676357],
#        [0.9881252 ],
#        [0.5747534 ],
#        [0.11577749],
#        [0.9247997 ],
#        [0.10839008],
#        [0.14953908],
#        [0.28542054],
#        [0.10361044],
#        [0.16354746],
#        [0.14320122],
#        [0.39251631],
#        [0.9863303 ],
#        [0.9897321 ],
#        [0.28602213],
#        [0.13031536],
#        [0.11084142],
#        [0.48185372],
#        [0.6904084 ],
#        [0.41467708],
#        [0.04636334],
#        [0.9893033 ],
#        [0.1458087 ],
#        [0.22882347],
#        [0.36432886],
#        [0.39658454],
#        [0.90200055],
#        [0.9463111 ],
#        [0.63399446],
#        [0.11476091],
#        [0.09842933],
#        [0.36815205],
#        [0.46956506],
#        [0.99147266],
#        [0.9870329 ],
#        [0.0869986 ],
#        [0.07449023],
#        [0.89968055],
#        [0.04464478],
#        [0.27173606],
#        [0.14493017],
#        [0.14953908],
#        [0.30299965],
#        [0.31133974],
#        [0.3517648 ],
#        [0.1394902 ],
#        [0.09842933],
#        [0.41525832],
#        [0.66374373],
#        [0.8535496 ],
#        [0.8502047 ],
#        [0.1406125 ],
#        [0.8362147 ],
#        [0.2880681 ],
#        [0.09583614],
#        [0.8628411 ],
#        [0.97008955],
#        [0.41347486],
#        [0.29976884],
#        [0.9803051 ],
#        [0.13255292],
#        [0.5470016 ],
#        [0.74009824],
#        [0.95048475],
#        [0.14953908],
#        [0.9780034 ],
#        [0.8739975 ],
#        [0.25459334],
#        [0.8182171 ],
#        [0.42732304],
#        [0.86979264],
#        [0.30136743],
#        [0.984814  ],
#        [0.09842933],
#        [0.21238315],
#        [0.43236583],
#        [0.1289501 ],
#        [0.6298775 ],
#        [0.9863303 ],
#        [0.09842933],
#        [0.13255292],
#        [0.14373751],
#        [0.2807356 ],
#        [0.9438885 ],
#        [0.14339708],
#        [0.19209835],
#        [0.0579835 ],
#        [0.14953908],
#        [0.40596148],
#        [0.10609056],
#        [0.41467708],
#        [0.48134726],
#        [0.19148721],
#        [0.9600493 ],
#        [0.32037628],
#        [0.16981019],
#        [0.51590925],
#        [0.03389573],
#        [0.18521775],
#        [0.8182171 ],
#        [0.9881363 ],
#        [0.0579835 ],
#        [0.5011105 ],
#        [0.11082175],
#        [0.08357126],
#        [0.98976094],
#        [0.680938  ],
#        [0.18823805],
#        [0.14322852],
#        [0.74009824],
#        [0.8504359 ],
#        [0.39658454],
#        [0.9854408 ],
#        [0.47428808],
#        [0.1015201 ],
#        [0.16981019],
#        [0.98516846],
#        [0.09842933],
#        [0.12353913],
#        [0.46433267],
#        [0.53591996],
#        [0.12090343],
#        [0.09842933],
#        [0.49440178],
#        [0.8987308 ],
#        [0.11476091],
#        [0.43113706],
#        [0.9319905 ],
#        [0.14963661],
#        [0.3558946 ],
#        [0.43236583],
#        [0.56884044],
#        [0.6092707 ],
#        [0.05351727],
#        [0.09842933],
#        [0.98326254],
#        [0.13174355],
#        [0.9892272 ],
#        [0.3922502 ],
#        [0.0950231 ],
#        [0.1137988 ],
#        [0.49440178],
#        [0.26843032],
#        [0.508523  ],
#        [0.9782124 ],
#        [0.11577749],
#        [0.09499189],
#        [0.090881  ],
#        [0.35703063],
#        [0.19148721],
#        [0.41347486],
#        [0.26791346],
#        [0.11476091],
#        [0.1015201 ],
#        [0.09842933],
#        [0.47779572],
#        [0.98121303],
#        [0.12090343],
#        [0.28403258],
#        [0.45532   ],
#        [0.18071753],
#        [0.07712517],
#        [0.1664163 ],
#        [0.1023693 ],
#        [0.41467708],
#        [0.9122048 ],
#        [0.2752619 ],
#        [0.5627879 ],
#        [0.74009824],
#        [0.34575933],
#        [0.10378309],
#        [0.04613923],
#        [0.07712517],
#        [0.08466921],
#        [0.0808169 ],
#        [0.11577749],
#        [0.04248701],
#        [0.9634756 ],
#        [0.10702655],
#        [0.17801817],
#        [0.39658454],
#        [0.822792  ],
#        [0.8182171 ],
#        [0.38530388],
#        [0.22380733],
#        [0.9774116 ],
#        [0.99371344],
#        [0.22902218],
#        [0.97996885],
#        [0.10609058],
#        [0.4332454 ],
#        [0.48185366],
#        [0.2972128 ],
#        [0.11476091],
#        [0.71182215],
#        [0.42650107],
#        [0.14339708],
#        [0.0846692 ],
#        [0.8950973 ]], dtype=float32)

# %%
result = pd.DataFrame(dict(y_test=y_test, pred=pred[:,0]))

# %%
result['pred'] = result['pred'].apply(lambda x: 1 if x >= 0.5 else 0)
result
# Out:
#      y_test  pred
# 625       0     0
# 566       0     0
# 459       0     0
# 804       1     0
# 338       1     0
# ..      ...   ...
# 184       1     1
# 607       1     0
# 624       0     0
# 103       0     0
# 387       1     1
#
# [268 rows x 2 columns]

# %%
from sklearn.metrics import classification_report
print(classification_report(result['y_test'], result['pred']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.90      0.85       165
#            1       0.80      0.65      0.72       103
#
#     accuracy                           0.80       268
#    macro avg       0.80      0.77      0.78       268
# weighted avg       0.80      0.80      0.80       268

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier(max_depth=3, random_state=42)
dtc.fit(mms_X_train, y_train)
pred2 = dtc.predict(mms_X_test)
print(classification_report(y_test, pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85       165
#            1       0.78      0.69      0.73       103
#
#     accuracy                           0.81       268
#    macro avg       0.80      0.78      0.79       268
# weighted avg       0.80      0.81      0.80       268

# %% [markdown]
# # Functional API를 이용한 함수형 모델
# * Sequential API는 단순히 층을 여러 개 쌓는 형태라 복잡한 모델 생성에 한계가 있음.
# * Functional API는 입력층과 출력층을 사용자가 직접 정의 가능
# * 다중입력(Multi-input), 다중출력(Multi-output)등 복잡한 모델을 정의할 수 있음
# * Input(shape=(독립변수 수))로 입력층 정의
# * 이전 층을 다음 층의 입력으로 사용
# * model()에 입력과 출력을 정의

# %%
# tensorflow 2.19버전용
from keras.layers import Input, Dense
from keras.models import Model

# %%
# 입력층
inputs = Input(shape=(mms_X_train.shape[1],))

# 은닉층
x = Dense(64, activation='relu')(inputs)
x = Dense(32, activation='relu')(x)
x = Dense(16, activation='relu')(x)

# 출력층
outputs = Dense(1, activation='sigmoid')(x)

# 모델 정의
model = Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 6)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,073 (12.00 KB)
#  Trainable params: 3,073 (12.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])
history = model.fit(mms_X_train, y_train, epochs=100,
                   batch_size=32,
                   validation_data=(mms_X_test, y_test))

pred = model.predict(mms_X_test)
pred = pd.DataFrame(pred)

pred = pred[0].apply(lambda x : 1 if x > 0.5 else 0)
print(classification_report(y_test,pred))

plt.figure(figsize=(8,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()
# Out:
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.4413 - loss: 0.7281 - val_accuracy: 0.6791 - val_loss: 0.6519
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6483 - loss: 0.6317 - val_accuracy: 0.7127 - val_loss: 0.5904
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7142 - loss: 0.5759 - val_accuracy: 0.7425 - val_loss: 0.5423
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7668 - loss: 0.5130 - val_accuracy: 0.7761 - val_loss: 0.5109
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7825 - loss: 0.5031 - val_accuracy: 0.7687 - val_loss: 0.4904
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7937 - loss: 0.4774 - val_accuracy: 0.7761 - val_loss: 0.4766
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8082 - loss: 0.4424 - val_accuracy: 0.7761 - val_loss: 0.4664
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8047 - loss: 0.4272 - val_accuracy: 0.7948 - val_loss: 0.4532
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8229 - loss: 0.4404 - val_accuracy: 0.7948 - val_loss: 0.4537
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8124 - loss: 0.4441 - val_accuracy: 0.8022 - val_loss: 0.4442
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7947 - loss: 0.4503 - val_accuracy: 0.7948 - val_loss: 0.4394
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8054 - loss: 0.4400 - val_accuracy: 0.7948 - val_loss: 0.4368
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8267 - loss: 0.4176 - val_accuracy: 0.8097 - val_loss: 0.4328
# Epoch 14/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8233 - loss: 0.4165 - val_accuracy: 0.8022 - val_loss: 0.4345
# Epoch 15/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8373 - loss: 0.4041 - val_accuracy: 0.8097 - val_loss: 0.4297
# Epoch 16/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8148 - loss: 0.4390 - val_accuracy: 0.8097 - val_loss: 0.4291
# Epoch 17/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8391 - loss: 0.3958 - val_accuracy: 0.8060 - val_loss: 0.4267
# Epoch 18/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7894 - loss: 0.4421 - val_accuracy: 0.8134 - val_loss: 0.4261
# Epoch 19/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8465 - loss: 0.4091 - val_accuracy: 0.7985 - val_loss: 0.4274
# Epoch 20/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8250 - loss: 0.4057 - val_accuracy: 0.8134 - val_loss: 0.4243
# Epoch 21/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8096 - loss: 0.4284 - val_accuracy: 0.8060 - val_loss: 0.4266
# Epoch 22/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8193 - loss: 0.4078 - val_accuracy: 0.8022 - val_loss: 0.4242
# Epoch 23/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8188 - loss: 0.4267 - val_accuracy: 0.7948 - val_loss: 0.4241
# Epoch 24/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8129 - loss: 0.4253 - val_accuracy: 0.8060 - val_loss: 0.4233
# Epoch 25/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8427 - loss: 0.3931 - val_accuracy: 0.8097 - val_loss: 0.4232
# Epoch 26/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8296 - loss: 0.4192 - val_accuracy: 0.7910 - val_loss: 0.4261
# Epoch 27/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8497 - loss: 0.3839 - val_accuracy: 0.8172 - val_loss: 0.4215
# Epoch 28/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8154 - loss: 0.3856 - val_accuracy: 0.7985 - val_loss: 0.4216
# Epoch 29/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.
100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8375 - loss: 0.3827 - val_accuracy: 0.7985 - val_loss: 0.4360
# Epoch 95/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8317 - loss: 0.4106 - val_accuracy: 0.8172 - val_loss: 0.4310
# Epoch 96/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8339 - loss: 0.3912 - val_accuracy: 0.8022 - val_loss: 0.4408
# Epoch 97/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8477 - loss: 0.3894 - val_accuracy: 0.8022 - val_loss: 0.4356
# Epoch 98/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8101 - loss: 0.4159 - val_accuracy: 0.8060 - val_loss: 0.4336
# Epoch 99/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8318 - loss: 0.3909 - val_accuracy: 0.7985 - val_loss: 0.4477
# Epoch 100/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8558 - loss: 0.3594 - val_accuracy: 0.8134 - val_loss: 0.4317
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step
#               precision    recall  f1-score   support
#
#            0       0.80      0.92      0.86       165
#            1       0.84      0.64      0.73       103
#
#     accuracy                           0.81       268
#    macro avg       0.82      0.78      0.79       268
# weighted avg       0.82      0.81      0.81       268

# %% [markdown]
# # class 형으로 만들기 (Model Subclass API)
# * class 형태의 모델 정의 방법
# * keras의 Model을 상속받아 작성

# %%
class Titanic(Model):
    def __init__(self):
        super(Titanic, self).__init__()
        self.dense1 = Dense(128, activation='relu')
        self.dense2 = Dense(64, activation='relu')
        self.dense3 = Dense(32, activation='relu')
        self.dense4 = Dense(16, activation='relu')
        self.classifier = Dense(1, activation='sigmoid')
        
    def call(self, inputs):
        x = self.dense1(inputs)
        x = self.dense2(x)
        x = self.dense3(x)
        x = self.dense4(x)
        return self.classifier(x)

# %%
model = Titanic()
print(model.summary())
# Out:
# Model: "titanic"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_8 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(mms_X_train, y_train, epochs=100, 
                    batch_size=32, validation_data=(mms_X_test, y_test))

pred = model.predict(mms_X_test)
pred = pd.DataFrame(pred)
pred = pred[0].apply(lambda x: 1 if x > 0.5 else 0)
print(classification_report(y_test, pred))
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()
# Out:
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.7660 - loss: 0.6758 - val_accuracy: 0.7761 - val_loss: 0.6300
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7683 - loss: 0.6112 - val_accuracy: 0.7761 - val_loss: 0.5289
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7674 - loss: 0.5179 - val_accuracy: 0.7724 - val_loss: 0.4705
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8017 - loss: 0.4409 - val_accuracy: 0.8060 - val_loss: 0.4524
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8011 - loss: 0.4488 - val_accuracy: 0.8060 - val_loss: 0.4498
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8012 - loss: 0.4573 - val_accuracy: 0.8172 - val_loss: 0.4406
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8029 - loss: 0.4476 - val_accuracy: 0.7873 - val_loss: 0.4518
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8287 - loss: 0.4196 - val_accuracy: 0.8134 - val_loss: 0.4432
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8347 - loss: 0.4149 - val_accuracy: 0.8172 - val_loss: 0.4335
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.