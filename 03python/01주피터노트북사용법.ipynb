# %% [markdown]
# < 마크다운 언어를 통한 필기 >
# # 셀복사:h1
# ## h2
# ### h3
# * 목록
# * 목록2
#   * 세부목록1
#     * 세부목록의 목록1
#   * 세부목록2
#
# <ul>
#     <li>목록</li>
#     <li>목록2</li>
# </ul>
#
# <h1>제목3</h1>
#
# 내용적기
# **굵게 표시**
#
# ### 링크 걸기
# [네이버링크].(https://www.naver.com)
#
# ### 이미지 넣기
# ![고양이].![%EA%B3%A0%EC%96%91%EC%9D%B4.jpg](attachment:%EA%B3%A0%EC%96%91%EC%9D%B4.jpg)
#
# ### 수식 넣기 (Tex 문법)
# $$ A \over B $$
# $$ (A \cap B) $$
