# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

# %% [markdown]
# # 기초 통계 개념 정리

# %% [markdown]
# ## 1) 대푯값: 데이터의 중심을 나타내는 값
# * 평균 (mean)
# * 중앙값 (median)
# * 최빈값 (mode)

# %% [markdown]
# ### (1) 평균(mean) $ \mu $
# * 모든 값의 총합을 값의 개수로 나눈 값
# * 극단적인 값(이상값/아웃라이어)이 있는 경우 평균에 영향을 미친다.
# * 모집단의 평균 $ \mu $
# * 표본집단의 평균 $ \bar{x} $
# * $$ 모평균: \mu = {\sum_{i=1}^N x_i \over N} $$
# * $$ 표본평균: \bar{x} = {\sum_{i=1}^N x_i \over n}$$

# %%
a = np.array([2,3,3,4,4,5,7,7,7,8])

# %%
a.mean()
# Out:
# np.float64(5.0)

# %% [markdown]
# ### (2) 중앙값(median)
# * 모든 데이터를 큰 순서대로 나열할 때 가운데 있는 값
# * 데이터의 개수가 홀수일 때는 정중앙의 값
# * 데이터의 개수가 짝수일 때는 정중앙 2개의 수의 평균값
# * 이상치가 있어도 영향을 받지 않는다.

# %%
a.T
# Out:
# array([2, 3, 3, 4, 4, 5, 7, 7, 7, 8])

# %%
a.median()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 a.median()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'median'

# %%
b = a.pop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 b = a.pop()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'pop'

# %% [markdown]
# ### (3) 최빈값(mode)
# * 표본에서 가장 많이 나온 수
# * 최빈값도 극단값에 영향을 받지 않음

# %% [markdown]
# 2020년 7%, 2021년 35%, 2022년 40$, 2023년 69% 매출 증가 -> 4년 평균 매출 증가율 ?

# %%
print('산술평균: ', pd.Series([7,35,40,69]).mean())
print('기하평균: ', gmean([7,35,40,69]))
# Out:
# 산술평균:  37.75
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 print('산술평균: ', pd.Series([7,35,40,69]).mean())
# ----> 2 print('기하평균: ', gmean([7,35,40,69]))
#
# NameError: name 'gmean' is not defined

# %% [markdown]
# ## 2) 도수 분포표와 히스토그램
# ### (1) 도수분포표(histogram 그래프)
# * 주어진 데이터를 일정한 범위로 나누고 그 범위에 출현하는 데이터 개수를 조사해 나타낸 표
# * 데이터의 구간 폭을 '계급(class)', 각 계급에 속하는 데이터 개수 '도수' 라고 한다.
# * 각 계급의 중앙값을 '계급값'이라 한다.
# * 도수분포표에서 도수가 큰 것을 '출현 횟수가 많다'고 하고
# * 가장 도수가 큰 계급의 계급값을 '최빈값'이라고 한다.
