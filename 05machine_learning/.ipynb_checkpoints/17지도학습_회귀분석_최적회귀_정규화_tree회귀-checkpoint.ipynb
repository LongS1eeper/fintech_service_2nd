# %% [markdown]
# # 회귀분석_최적회귀_정규화_tree회귀

# %% [markdown]
# ## 보스턴 집값 데이터 회귀분석

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import koreanize_matplotlib
import seaborn as sns

# %%
data = pd.read_csv("https://raw.githubusercontent.com/haram4th/ADsP/main/01%EB%B3%B4%EC%8A%A4%ED%84%B4%EC%A7%91%EA%B0%92%EB%8D%B0%EC%9D%B4%ED%84%B0.csv")

# %%
data
# Out:
#          범죄율  25,000평방피트초과  비소매상업지역비율  찰스강경계  농축 일산화질소  가구당평균방수  1940년이전건축비율  \
# 0    0.00632          18.0       2.31      0     0.538    6.575         65.2
# 1    0.02731           0.0       7.07      0     0.469    6.421         78.9
# 2    0.02729           0.0       7.07      0     0.469    7.185         61.1
# 3    0.03237           0.0       2.18      0     0.458    6.998         45.8
# 4    0.06905           0.0       2.18      0     0.458    7.147         54.2
# ..       ...           ...        ...    ...       ...      ...          ...
# 501  0.06263           0.0      11.93      0     0.573    6.593         69.1
# 502  0.04527           0.0      11.93      0     0.573    6.120         76.7
# 503  0.06076           0.0      11.93      0     0.573    6.976         91.0
# 504  0.10959           0.0      11.93      0     0.573    6.794         89.3
# 505  0.04741           0.0      11.93      0     0.573    6.030         80.8
#
#      직업센터접근성  도로접근성   재산세율  학생/교사비율    흑인비율  하위계층비율  주택가격
# 0     4.0900      1  296.0     15.3  396.90    4.98  24.0
# 1     4.9671      2  242.0     17.8  396.90    9.14  21.6
# 2     4.9671      2  242.0     17.8  392.83    4.03  34.7
# 3     6.0622      3  222.0     18.7  394.63    2.94  33.4
# 4     6.0622      3  222.0     18.7  396.90    5.33  36.2
# ..       ...    ...    ...      ...     ...     ...   ...
# 501   2.4786      1  273.0     21.0  391.99    9.67  22.4
# 502   2.2875      1  273.0     21.0  396.90    9.08  20.6
# 503   2.1675      1  273.0     21.0  396.90    5.64  23.9
# 504   2.3889      1  273.0     21.0  393.45    6.48  22.0
# 505   2.5050      1  273.0     21.0  396.90    7.88  11.9
#
# [506 rows x 14 columns]

# %%
# 찰스강경계, 도로접근성은 int 지만 범주형 변수
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   범죄율           506 non-null    float64
#  1   25,000평방피트초과  506 non-null    float64
#  2   비소매상업지역비율     506 non-null    float64
#  3   찰스강경계         506 non-null    int64
#  4   농축 일산화질소      506 non-null    float64
#  5   가구당평균방수       506 non-null    float64
#  6   1940년이전건축비율   506 non-null    float64
#  7   직업센터접근성       506 non-null    float64
#  8   도로접근성         506 non-null    int64
#  9   재산세율          506 non-null    float64
#  10  학생/교사비율       506 non-null    float64
#  11  흑인비율          506 non-null    float64
#  12  하위계층비율        506 non-null    float64
#  13  주택가격          506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
data.isna().sum()
# Out:
# 범죄율             0
# 25,000평방피트초과    0
# 비소매상업지역비율       0
# 찰스강경계           0
# 농축 일산화질소        0
# 가구당평균방수         0
# 1940년이전건축비율     0
# 직업센터접근성         0
# 도로접근성           0
# 재산세율            0
# 학생/교사비율         0
# 흑인비율            0
# 하위계층비율          0
# 주택가격            0
# dtype: int64

# %%
data.describe()
# Out:
#               범죄율  25,000평방피트초과   비소매상업지역비율       찰스강경계    농축 일산화질소  \
# count  506.000000    506.000000  506.000000  506.000000  506.000000
# mean     3.613524     11.363636   11.136779    0.069170    0.554695
# std      8.601545     23.322453    6.860353    0.253994    0.115878
# min      0.006320      0.000000    0.460000    0.000000    0.385000
# 25%      0.082045      0.000000    5.190000    0.000000    0.449000
# 50%      0.256510      0.000000    9.690000    0.000000    0.538000
# 75%      3.677083     12.500000   18.100000    0.000000    0.624000
# max     88.976200    100.000000   27.740000    1.000000    0.871000
#
#           가구당평균방수  1940년이전건축비율     직업센터접근성       도로접근성        재산세율  \
# count  506.000000   506.000000  506.000000  506.000000  506.000000
# mean     6.284634    68.574901    3.795043    9.549407  408.237154
# std      0.702617    28.148861    2.105710    8.707259  168.537116
# min      3.561000     2.900000    1.129600    1.000000  187.000000
# 25%      5.885500    45.025000    2.100175    4.000000  279.000000
# 50%      6.208500    77.500000    3.207450    5.000000  330.000000
# 75%      6.623500    94.075000    5.188425   24.000000  666.000000
# max      8.780000   100.000000   12.126500   24.000000  711.000000
#
#           학생/교사비율        흑인비율      하위계층비율        주택가격
# count  506.000000  506.000000  506.000000  506.000000
# mean    18.455534  356.674032   12.653063   22.532806
# std      2.164946   91.294864    7.141062    9.197104
# min     12.600000    0.320000    1.730000    5.000000
# 25%     17.400000  375.377500    6.950000   17.025000
# 50%     19.050000  391.440000   11.360000   21.200000
# 75%     20.200000  396.225000   16.955000   25.000000
# max     22.000000  396.900000   37.970000   50.000000

# %%
data.columns
# Out:
# Index(['범죄율', '25,000평방피트초과', '비소매상업지역비율', '찰스강경계', '농축 일산화질소', '가구당평균방수',
#        '1940년이전건축비율', '직업센터접근성', '도로접근성', '재산세율', '학생/교사비율', '흑인비율', '하위계층비율',
#        '주택가격'],
#       dtype='object')

# %%
sns.boxplot(data[['범죄율', '25,000평방피트초과', '비소매상업지역비율']])
# Out:
# <Axes: >

# %%
sns.boxplot(data[['농축 일산화질소', '가구당평균방수', '1940년이전건축비율', '직업센터접근성']])
# Out:
# <Axes: >

# %%
sns.boxplot(data[['재산세율', '학생/교사비율', '흑인비율', '하위계층비율']])
# Out:
# <Axes: >

# %%
cols = data.columns[:-1]

# %%
for col in cols:
    print("="*30,col,"="*30)
    sns.histplot(data[col])
    plt.show()
# Out:
# ============================== 범죄율 ==============================
# ============================== 25,000평방피트초과 ==============================
# ============================== 비소매상업지역비율 ==============================
# ============================== 찰스강경계 ==============================
# ============================== 농축 일산화질소 ==============================
# ============================== 가구당평균방수 ==============================
# ============================== 1940년이전건축비율 ==============================
# ============================== 직업센터접근성 ==============================
# ============================== 도로접근성 ==============================
# ============================== 재산세율 ==============================
# ============================== 학생/교사비율 ==============================
# ============================== 흑인비율 ==============================
# ============================== 하위계층비율 ==============================

# %%
# 수치형 변수가 매우 많으므로 스피어만 상관관계
plt.figure(figsize=(20,20))
sns.heatmap(data.corr(method='spearman'), annot=True, linewidth=1)
# Out:
# <Axes: >

# %%
X = data.drop('주택가격', axis=1)
y = data['주택가격']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train2 = X_train.copy()
X_test2 = X_test.copy()

# %% [markdown]
# #### 스케일 맞추기
# * 이상치가 좀 있었으므로 RobustScaler로 스케일 조정

# %%
from sklearn.preprocessing import RobustScaler

# %%
rs = RobustScaler()
rs.fit(X_train)
rs_X_train = rs.transform(X_train)
rs_X_test = rs.transform(X_test)

# 스케일 맞추는 과정에서 인덱스가 날아가므로 직접 지정
rs_X_train = pd.DataFrame(rs_X_train, columns = X_train.columns, index=X_train.index)
rs_X_test = pd.DataFrame(rs_X_test, columns = X_test.columns, index=X_test.index)

# %%
rs_X_train
# Out:
#           범죄율  25,000평방피트초과  비소매상업지역비율  찰스강경계  농축 일산화질소   가구당평균방수  \
# 5   -0.070845           0.0  -0.579029    0.0 -0.441989  0.255601
# 116 -0.039048           0.0   0.024672    0.0  0.049724 -0.065005
# 45  -0.026596           0.0  -0.214341    0.0 -0.497238 -0.688545
# 16   0.249243           0.0  -0.119507    0.0  0.000000 -0.369202
# 468  4.788193           0.0   0.648419    0.0  0.232044 -0.380562
# ..        ...           ...        ...    ...       ...       ...
# 106 -0.026665           0.0  -0.087124    0.0 -0.099448 -0.494162
# 270  0.013331           1.0  -0.210486    0.0 -0.408840 -0.468918
# 348 -0.075484           4.0  -0.592136    0.0 -0.569061  0.514358
# 435  3.408139           0.0   0.648419    0.0  1.116022  0.506784
# 102 -0.008674           0.0  -0.087124    0.0 -0.099448  0.224045
#
#      1940년이전건축비율   직업센터접근성  도로접근성      재산세율   학생/교사비율       흑인비율    하위계층비율
# 5      -0.393045  0.888157  -0.10 -0.279070  0.028169   0.129964 -0.610414
# 116    -0.102213 -0.113375   0.05  0.263566 -0.225352   0.087674  0.119092
# 45     -0.917808  0.599068  -0.10 -0.250646 -0.197183   0.273337 -0.076368
# 16     -1.012645  0.418185  -0.05 -0.059432  0.676056  -0.244972 -0.464085
# 468    -0.133825 -0.059784   0.95  0.868217  0.450704  -1.178958  0.769559
# ..           ...       ...    ...       ...       ...        ...       ...
# 106     0.306639 -0.269402   0.00  0.139535  0.647887   0.209902  0.826168
# 270    -0.742887  0.397265  -0.10 -0.276486  0.000000  -0.152140  0.221629
# 348    -1.004215  1.574001  -0.05 -0.129199 -0.450704  -0.034038 -0.527103
# 435     0.363541 -0.295341   0.95  0.868217  0.450704 -14.530686  1.318558
# 102     0.169652 -0.118004   0.00  0.139535  0.647887 -16.544611 -0.031509
#
# [354 rows x 13 columns]

# %% [markdown]
# # statsmodels 선형회귀분석

# %%
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
# 상수항 추가
rs_X_train_const = sm.add_constant(rs_X_train)
rs_X_test_const = sm.add_constant(rs_X_test)

# %%
ols = sm.OLS(y_train, rs_X_train_const).fit()
pred = ols.predict(rs_X_test_const)
print("MAE: ", mean_absolute_error(y_test, pred))
print("MSE: ", mean_squared_error(y_test, pred))
print("RMSE: ", np.sqrt(mean_absolute_error(y_test, pred)))
print("R2: ", r2_score(y_test, pred))
# Out:
# MAE:  3.162709871457414
# MSE:  21.517444231177297
# RMSE:  1.7784009310212965
# R2:  0.711226005748492

# %%
print(ols.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   주택가격   R-squared:                       0.743
# Model:                            OLS   Adj. R-squared:                  0.734
# Method:                 Least Squares   F-statistic:                     75.81
# Date:                Thu, 08 May 2025   Prob (F-statistic):           4.96e-92
# Time:                        14:33:42   Log-Likelihood:                -1053.8
# No. Observations:                 354   AIC:                             2136.
# Df Residuals:                     340   BIC:                             2190.
# Df Model:                          13
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           23.9494      0.408     58.755      0.000      23.148      24.751
# 범죄율             -0.4270      0.131     -3.271      0.001      -0.684      -0.170
# 25,000평방피트초과     0.7162      0.353      2.029      0.043       0.022       1.411
# 비소매상업지역비율        0.6423      0.944      0.680      0.497      -1.215       2.499
# 찰스강경계            3.1198      1.037      3.010      0.003       1.081       5.159
# 농축 일산화질소        -2.7905      0.860     -3.246      0.001      -4.481      -1.100
# 가구당평균방수          3.2143      0.393      8.181      0.000       2.442       3.987
# 1940년이전건축비율     -0.5134      0.766     -0.671      0.503      -2.019       0.992
# 직업센터접근성         -4.6112      0.804     -5.734      0.000      -6.193      -3.029
# 도로접근성            4.8545      1.639      2.963      0.003       1.632       8.077
# 재산세율            -3.3678      1.786     -1.886      0.060      -6.880       0.145
# 학생/교사비율         -3.2329      0.548     -5.905      0.000      -4.310      -2.156
# 흑인비율             0.2287      0.065      3.534      0.000       0.101       0.356
# 하위계층비율          -5.1223      0.556     -9.219      0.000      -6.215      -4.029
# ==============================================================================
# Omnibus:                      115.779   Durbin-Watson:                   2.087
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              458.270
# Skew:                           1.381   Prob(JB):                    3.08e-100
# Kurtosis:                       7.842   Cond. No.                         45.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
result = pd.DataFrame(dict(y_test=y_test, pred=pred))
result
# Out:
#      y_test       pred
# 173    23.6  28.648960
# 274    32.4  36.495014
# 491    13.6  15.411193
# 72     22.8  25.403213
# 452    16.1  18.855280
# ..      ...        ...
# 441    17.1  17.403672
# 23     14.5  13.385941
# 225    50.0  39.983425
# 433    14.3  16.682863
# 447    12.6  18.285618
#
# [152 rows x 2 columns]

# %%
result['잔차'] = result['y_test'] - result['pred']
result['잔차제곱'] = (result['잔차'] ** 2)
result['MSE'] = result['잔차제곱'].mean()
result['RMSE'] = result['MSE'].apply(np.sqrt)

# %% [markdown]
# # 최적회기 구하기 (단계별 변수 선택법)
# * 1) 전진선택법
# * 2) 후진제거법

# %%
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %% [markdown]
# * 전진선택법으로 분석

# %%
sfs_fw = SequentialFeatureSelector(
    estimator=model,
    direction='forward',
    scoring='r2',
    cv = 5,
    n_jobs=4
    )
sfs_fw.fit(rs_X_train_const, y_train)
print(sfs_fw.get_support())
selected_cols = rs_X_train_const.columns[sfs_fw.get_support()]
print('전진선택법으로 선택된 컬럼: ', list(selected_cols))
# Out:
# [False  True False False  True  True  True False  True False False  True
#  False  True]
# 전진선택법으로 선택된 컬럼:  ['범죄율', '찰스강경계', '농축 일산화질소', '가구당평균방수', '직업센터접근성', '학생/교사비율', '하위계층비율']

# %%
print("원래 컬럼: ", len(rs_X_train_const.columns))
print("selected_cols: ", len(selected_cols))
# Out:
# 원래 컬럼:  14
# selected_cols:  7

# %%
fw_X_train = rs_X_train_const[['const','범죄율','찰스강경계','농축 일산화질소','가구당평균방수','직업센터접근성','학생/교사비율','하위계층비율']]
fw_X_test = rs_X_test_const[['const','범죄율','찰스강경계','농축 일산화질소','가구당평균방수','직업센터접근성','학생/교사비율','하위계층비율']]

# %%
ols2 = sm.OLS(y_train, fw_X_train).fit()
pred = ols2.predict(fw_X_test)
print("MAE: ", mean_absolute_error(y_test, pred))
print("MSE: ", mean_squared_error(y_test, pred))
print("RMSE: ", np.sqrt(mean_absolute_error(y_test, pred)))
print("R2: ", r2_score(y_test, pred))
# Out:
# MAE:  3.310296758822148
# MSE:  23.361549390774957
# RMSE:  1.8194220947383672
# R2:  0.6864772666772769
