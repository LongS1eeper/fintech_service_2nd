# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # pandas 에서 다루는 데이터 타입 2가지
# ## 1) DataFrame: 2차원의 표현식 데이터
# * python의 dict와도 비슷 하나의 key에 list 형태의 value가 매칭되어있는 형태
# * {key : [value1, value2, value3], key2 : [value1, value2, value3]}
# ## 2) Series: 1차원의 벡터형식 데이터
# * python의 list, tuple, ndarray의 1차원 상태와 비슷

# %%
import pandas as pd

# %% [markdown]
# # 데이터 프레임 만들기
# pd.DataFrame({key1 : [value1, value2], key2 : [value1, value2]}

# %%
df = pd.DataFrame(
            {'이름' : ['홍길동', '둘리', '또치', '도우너'],
             '주소' : ['서울', '의정부', '고양', '성남'],
             '취미' : ['음악감상', '놀기', '달리기', '바이올린']}
            )

# %%
df['이름']
# Out:
# 0    홍길동
# 1     둘리
# 2     또치
# 3    도우너
# Name: 이름, dtype: object

# %%
df.shape
# Out:
# (4, 3)

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# # Series 사용법
# * pd.Series([리스트자료/튜플], name = '컬럼명')
# * 이름을 가지고 있는 list/벡터
# * dataframe에서 컬럼 1개를 잘라온 형태

# %%
ages = pd.Series([22, 53, 35], name='나이')
ages
# Out:
# 0    22
# 1    53
# 2    35
# Name: 나이, dtype: int64

# %%
ages.median()
# Out:
# np.float64(35.0)

# %%
ages.cumsum()
# Out:
# 0     22
# 1     75
# 2    110
# Name: 나이, dtype: int64

# %%
ages.mean()
# Out:
# np.float64(36.666666666666664)

# %% [markdown]
# # 판다스에서 자료 불러오기, 저장하기
# * csv, tsv, excel, json, html, sql
# * pd.read_확장자명(파일경로, 옵션)

# %%
df_excel = pd.read_excel("./data/Online Retail.xlsx")
df_excel
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
# 첫 행이 컬럼이 아닌 경우 header 매개변수로 조작
df_excel2 = pd.read_excel("./data/아파트(매매)_실거래가_20240806113828.xlsx", header=12, index_col = 'NO')
df_excel2
# Out:
# C:\Users\Admin\miniforge3\envs\fintech\lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                        시군구      번지    본번  부번                단지명   전용면적(㎡)  \
# NO
# 1         서울특별시 영등포구 당산동5가      42    42   0          당산삼성래미안4차  115.7800
# 2      강원특별자치도 원주시 지정면 가곡리    1512  1512   0  원주롯데캐슬골드파크1차(5단지)   84.9644
# 3        대구광역시 달성군 화원읍 구라리    1650  1650   0             대곡역래미안   84.5958
# 4             광주광역시 남구 진월동   312-7   312   7                 광명   70.6250
# 5             광주광역시 남구 진월동  331-93   331  93                 중흥   84.8400
# ...                    ...     ...   ...  ..                ...       ...
# 37576        서울특별시 송파구 장지동     849   849   0          송파파인타운3단지   84.9800
# 37577        부산광역시 사상구 모라동     552   552   0               백양그린   41.3000
# ...

# %%
# 특정 컬럼만 가져오고 싶은 경우 usecols 매개변수 이용
df_excel2 = pd.read_excel("./data/아파트(매매)_실거래가_20240806113828.xlsx", header=12, usecols = [1,2,3,4,5])
df_excel2
# Out:
# C:\Users\Admin\miniforge3\envs\fintech\lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                        시군구      번지    본번  부번                단지명
# 0         서울특별시 영등포구 당산동5가      42    42   0          당산삼성래미안4차
# 1      강원특별자치도 원주시 지정면 가곡리    1512  1512   0  원주롯데캐슬골드파크1차(5단지)
# 2        대구광역시 달성군 화원읍 구라리    1650  1650   0             대곡역래미안
# 3             광주광역시 남구 진월동   312-7   312   7                 광명
# 4             광주광역시 남구 진월동  331-93   331  93                 중흥
# ...                    ...     ...   ...  ..                ...
# 37575        서울특별시 송파구 장지동     849   849   0          송파파인타운3단지
# 37576        부산광역시 사상구 모라동     552   552   0               백양그린
# 37577        광주광역시 광산구 비아동   152-5   152   5                 호반
# 37578        부산광역시 사상구 모라동     552   552   0               백양그린
# ...

# %%
df_csv = pd.read_csv("./data/아파트(매매)_실거래가_20240806113828.csv", header = 12)
df_csv
# Out:
#           NO                  시군구      번지    본번  부번                단지명  \
# 0          1     서울특별시 영등포구 당산동5가      42    42   0          당산삼성래미안4차
# 1          2  강원특별자치도 원주시 지정면 가곡리    1512  1512   0  원주롯데캐슬골드파크1차(5단지)
# 2          3    대구광역시 달성군 화원읍 구라리    1650  1650   0             대곡역래미안
# 3          4         광주광역시 남구 진월동   312-7   312   7                 광명
# 4          5         광주광역시 남구 진월동  331-93   331  93                 중흥
# ...      ...                  ...     ...   ...  ..                ...
# 37575  37576        서울특별시 송파구 장지동     849   849   0          송파파인타운3단지
# 37576  37577        부산광역시 사상구 모라동     552   552   0               백양그린
# 37577  37578        광주광역시 광산구 비아동   152-5   152   5                 호반
# 37578  37579        부산광역시 사상구 모라동     552   552   0               백양그린
# 37579  37580         대구광역시 북구 읍내동  1366-2  1366   2               칠곡보성
#
#         전용면적(㎡)    계약년월  계약일 거래금액(만원)  ...   층  매수자 매도자  건축년도            도로명  \
# ...

# %%
ddf_json = pd.read_json('./data/서울특별시_관광지입장정보_2011_2016.json')
df_json
# Out:
#     ForNum  NatNum  addrCd gungu      resNm  rnum   sido  yyyymm
# 0    44722   75991    1111   종로구        창덕궁     1  서울특별시  201112
# 1        0   11017    1111   종로구        운현궁     2  서울특별시  201112
# 2   132399  237330    1111   종로구        경복궁     3  서울특별시  201112
# 3     3133   21267    1111   종로구        창경궁     4  서울특별시  201112
# 4    18226   24223    1111   종로구         종묘     5  서울특별시  201112
# ..     ...     ...     ...   ...        ...   ...    ...     ...
# 62    5588   44232    1141  서대문구  서대문형무소역사관     8  서울특별시  201512
# 63       0   22587    1141  서대문구  서대문자연사박물관     9  서울특별시  201512
# 64   29520    8822    1144   마포구    트릭아이미술관    10  서울특별시  201512
# 65       3    1647    1165   서초구      헌릉ㆍ인릉    11  서울특별시  201512
# 66     492   14454    1168   강남구      선릉·정릉    12  서울특별시  201512
#
# [67 rows x 8 columns]

# %%
df_html = pd.read_html("./data/corpList.htm")
df_html
# Out:
# [    Unnamed: 0                             Unnamed: 1  \
#  0     한국제15호스팩                             금융 지원 서비스업
#  1       에스오에스랩  측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
#  2   미래에셋비전스팩6호                             금융 지원 서비스업
#  3   에이치엠씨제7호스팩                             금융 지원 서비스업
#  4        파라다이스                     유원지 및 기타 오락관련 서비스업
#  5       한중엔시에스      전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업
#  6     KB제29호스팩                             금융 지원 서비스업
#  7   미래에셋비전스팩5호                             금융 지원 서비스업
#  8     씨어스테크놀로지                             의료용 기기 제조업
#  9     한국제14호스팩                             금융 지원 서비스업
#  10   디비금융스팩12호                                 기타 금융업
#  11        라메디텍                             의료용 기기 제조업
#  12       그리드위즈                 그외 기타 전문, 과학 및 기술 서비스업
#  13       다원넥스뷰                        사진장비 및 광학기기 제조업
#  14  미래에셋비전스팩4호                             금융 지원 서비스업
#
#                                             Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# ...

# %% [markdown]
# DB에서 자료 읽어오기

# %% [markdown]
# # 타이타닉 데이터셋으로 pandas 기능 익히기

# %%
df = pd.read_csv("./data/Taitanic_train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# * 데이터의 일부만 보기
# * 앞쪽 head(행개수), 뒷쪽 tail(행개수)

# %%
df.tail(4)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# # .info()
# * 컬럼명, null이 아닌 개수, 데이터 타입 등 확인

# %%
# 결측값 확인  ( 891 non-null = 891개의 값이 null이 아님)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # describe()
# * 데이터 프레임의 숫자 데이터의 기초 통계를 보여주는 함수
# * count, mean, std, min, 25%, 50%, 75%, max

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # 판다스 데이터 프레임에서 일부 자료만 추출하기
# * 데이터프레임에서 1개 컬럼만 가져오기

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 0            1         0       3  Graham, Miss. Margaret Edith  male  22.0
#
#    SibSp  Parch     Ticket  Fare Cabin Embarked
# 0      1      0  A/5 21171  7.25   NaN        S

# %%
df['Name']   # type = Series
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %% [markdown]
# * 2개 이상의 컬럼을 가져오기

# %%
df[['Name','Age']]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %% [markdown]
# * 데이터 프레임의 컬럼 순서 바꾸기

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[['Fare', 'Cabin', 'PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Embarked']]
# Out:
#         Fare Cabin  PassengerId  Survived  Pclass  \
# 0     7.2500   NaN            1         0       3
# 1    71.2833   C85            2         1       1
# 2     7.9250   NaN            3         1       3
# 3    53.1000  C123            4         1       1
# 4     8.0500   NaN            5         0       3
# ..       ...   ...          ...       ...     ...
# 886  13.0000   NaN          887         0       2
# 887  30.0000   B42          888         1       1
# 888  23.4500   NaN          889         0       3
# 889  30.0000  C148          890         1       1
# 890   7.7500   NaN          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# ...

# %% [markdown]
# # 데이터프레임에서 일부 컬럼만 가져오기 2
# * loc: 인덱스 이름과 컬럼명으로 데이터의 일부를 추출해 가져옴
#     * df.loc[시작_row_인덱스 : 끝_row_인덱스, ['컬럼명1', '컬럼명2']
# * iloc: 인덱스를 이용해 슬라이싱으로 데이터의 일부를 가져옴
#     * df.iloc[시작_row_index : 끝_row_index, 시작_column_index : 끝_column_index]

# %% [markdown]
# ### loc[시작_row_인덱스 : 끝_row_인덱스, ['컬럼명1', '컬럼명2']

# %%
df.loc[100:130, ['Name', 'Age']]
# Out:
#                                   Name   Age
# 100            Petranec, Miss. Matilda  28.0
# 101   Petroff, Mr. Pastcho ("Pentcho")   NaN
# 102          White, Mr. Richard Frasar  21.0
# 103         Johansson, Mr. Gustaf Joel  33.0
# 104     Gustafsson, Mr. Anders Vilhelm  37.0
# 105              Mionoff, Mr. Stoytcho  28.0
# 106   Salkjelsvik, Miss. Anna Kristine  21.0
# 107             Moss, Mr. Albert Johan   NaN
# 108                    Rekic, Mr. Tido  38.0
# 109                Moran, Miss. Bertha   NaN
# 110     Porter, Mr. Walter Chamberlain  47.0
# 111               Zabour, Miss. Hileni  14.5
# 112             Barton, Mr. David John  22.0
# 113            Jussila, Miss. Katriina  20.0
# 114              Attalah, Miss. Malake  17.0
# 115              Pekoniemi, Mr. Edvard  21.0
# 116               Connors, Mr. Patrick  70.5
# 117    Turpin, Mr. William John Robert  29.0
# 118           Baxter, Mr. Quigg Edmond  24.0
# 119  Andersson, Miss. Ellis Anna Maria   2.0
# ...

# %%
# Nan 값을 29로 설정
df.loc[101,['Age']] = 29
display(df.loc[101,['Age']])
# Out:
# Age    29.0
# Name: 101, dtype: object

# %% [markdown]
# ### df.iloc[시작_row_index : 끝_row_index, 시작_column_index : 끝_column_index]

# %%
# 인덱스로 행과 열 모두 조작
df.iloc[0:13, 0:5]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
#
#                                                  Name     Sex
# 0                             Braund, Mr. Owen Harris    male
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                              Heikkinen, Miss. Laina  female
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                            Allen, Mr. William Henry    male
# 5                                    Moran, Mr. James    male
# ...

# %%
df.iloc[4:, -5:]
# Out:
#      Parch      Ticket     Fare Cabin Embarked
# 4        0      373450   8.0500   NaN        S
# 5        0      330877   8.4583   NaN        Q
# 6        0       17463  51.8625   E46        S
# 7        1      349909  21.0750   NaN        S
# 8        2      347742  11.1333   NaN        S
# ..     ...         ...      ...   ...      ...
# 886      0      211536  13.0000   NaN        S
# 887      0      112053  30.0000   B42        S
# 888      2  W./C. 6607  23.4500   NaN        S
# 889      0      111369  30.0000  C148        C
# 890      0      370376   7.7500   NaN        Q
#
# [887 rows x 5 columns]

# %%
df.iloc[4,4]
# Out:
# 'male'

# %%
df.iloc[:10:-1, ::-1]  # 행 10개까지 거꾸로, 열 거꾸로 출력
# Out:
#     Embarked Cabin     Fare      Ticket  Parch  SibSp   Age     Sex  \
# 890        Q   NaN   7.7500      370376      0      0  32.0    male
# 889        C  C148  30.0000      111369      0      0  26.0    male
# 888        S   NaN  23.4500  W./C. 6607      2      1   NaN  female
# 887        S   B42  30.0000      112053      0      0  19.0  female
# 886        S   NaN  13.0000      211536      0      0  27.0    male
# ..       ...   ...      ...         ...    ...    ...   ...     ...
# 15         S   NaN  16.0000      248706      0      0  55.0  female
# 14         S   NaN   7.8542      350406      0      0  14.0  female
# 13         S   NaN  31.2750      347082      5      1  39.0    male
# 12         S   NaN   8.0500   A/5. 2151      0      0  20.0    male
# 11         S  C103  26.5500      113783      0      0  58.0  female
#
#                                          Name  Pclass  Survived  PassengerId
# ...

# %% [markdown]
# * 특정 컬럼에서 유일값(중복되지 않은 고유한 값)출력하기
# * .unique()

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %% [markdown]
# * .nunique()
# * 유일값의 개수를 출력
# * nan값은 무시

# %%
df['Embarked'].nunique()
# Out:
# 3

# %% [markdown]
# * .value_counts()
# * 옵션 value의 개수에 따라서 오름차순, 내림차순 정렬

# %%
df['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 30.00    25
#          ..
# 24.50     1
# 0.67      1
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
df['Age'].value_counts(sort=False)
# Out:
# Age
# 22.00    27
# 38.00    11
# 26.00    18
# 35.00    18
# 54.00     8
#          ..
# 0.67      1
# 30.50     2
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %% [markdown]
# * 데이터를 정렬하는 함수
# * sort_values(by='컬럼명)
# * order by

# %%
df.sort_values(by='Age', ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %% [markdown]
# 기준 컬럼 2개로 정렬할 때

# %%
df.sort_values(by=['Pclass','Age'], ascending=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 851          852         0       3
# 116          117         0       3
# 280          281         0       3
# 483          484         1       3
# 326          327         0       3
# ..           ...       ...     ...
# 766          767         0       1
# 793          794         0       1
# 815          816         0       1
# 839          840         1       1
# 849          850         1       1
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 851                           Svensson, Mr. Johan    male  74.0      0      0
# 116                          Connors, Mr. Patrick    male  70.5      0      0
# 280                              Duane, Mr. Frank    male  65.0      0      0
# 483                        Turkula, Mrs. (Hedwig)  female  63.0      0      0
# 326                     Nysveen, Mr. Johan Hansen    male  61.0      0      0
# ...

# %% [markdown]
# * 컬럼을 인덱스로 지정하기
# * set_index(컬럼명)

# %%
df.set_index(["PassengerId", 'Name'])
# Out:
#                                                                 Survived  \
# PassengerId Name
# 1           Braund, Mr. Owen Harris                                    0
# 2           Cumings, Mrs. John Bradley (Florence Briggs Tha...         1
# 3           Heikkinen, Miss. Laina                                     1
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)               1
# 5           Allen, Mr. William Henry                                   0
# ...                                                                  ...
# 887         Montvila, Rev. Juozas                                      0
# 888         Graham, Miss. Margaret Edith                               1
# 889         Johnston, Miss. Catherine Helen "Carrie"                   0
# 890         Behr, Mr. Karl Howell                                      1
# 891         Dooley, Mr. Patrick                                        0
#
#                                                                 Pclass  \
# ...

# %%
df.loc[(889, 'Johnston, Miss. Catherine Helen "Carrie"'), ['Pclass','Age']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 df.loc[(889, 'Johnston, Miss. Catherine Helen "Carrie"'), ['Pclass','Age']]
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\indexing.py:1375, in _LocIndexer._getitem_tuple(self, tup)
#    1373 # ugly hack for GH #836
#    1374 if self._multi_take_opportunity(tup):
# -> 1375     return self._multi_take(tup)
#    1377 return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
df.iloc[888:, [1,3]]
# Out:
#      Survived                                      Name
# 888         0  Johnston, Miss. Catherine Helen "Carrie"
# 889         1                     Behr, Mr. Karl Howell
# 890         0                       Dooley, Mr. Patrick

# %% [markdown]
# * 인덱스를 숫자로 초기화
# * reset_index(drop=True/False)

# %%
df.reset_index(drop=True)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# * 컬럼이름 출력하기, 바꾸기
# * df.columns

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# * 컬럼이름 변경하기
# * rename(columns={'원래 이름':'새이름', '원래이름2':'새이름2'}

# %%
df.rename(columns={'PassengerId':'Pid','Survived':'surv'}, inplace=True)
df
# Out:
#      Pid  surv  Pclass                                               Name  \
# 0      1     0       3                            Braund, Mr. Owen Harris
# 1      2     1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      3     1       3                             Heikkinen, Miss. Laina
# 3      4     1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      5     0       3                           Allen, Mr. William Henry
# ..   ...   ...     ...                                                ...
# 886  887     0       2                              Montvila, Rev. Juozas
# 887  888     1       1                       Graham, Miss. Margaret Edith
# 888  889     0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889  890     1       1                              Behr, Mr. Karl Howell
# 890  891     0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# * df.columns 로 출력되는 리스트 길이와 같은 새로운 이름의 리스트로 덮어쓰기

# %%
df.columns
# Out:
# Index(['Pid', 'surv', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
newName = ['승객번호', '생존여부', '선실등급', '이름', '성별', '나이', '형제자매수', '부모자식수',
       '티켓번호', '티켓가격', '선실번호', '목적지']

# %%
df.columns = newName
df
# Out:
#      승객번호  생존여부  선실등급                                                 이름  \
# 0       1     0     3                            Braund, Mr. Owen Harris
# 1       2     1     1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       3     1     3                             Heikkinen, Miss. Laina
# 3       4     1     1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       5     0     3                           Allen, Mr. William Henry
# ..    ...   ...   ...                                                ...
# 886   887     0     2                              Montvila, Rev. Juozas
# 887   888     1     1                       Graham, Miss. Margaret Edith
# 888   889     0     3           Johnston, Miss. Catherine Helen "Carrie"
# 889   890     1     1                              Behr, Mr. Karl Howell
# 890   891     0     3                                Dooley, Mr. Patrick
#
#          성별    나이  형제자매수  부모자식수              티켓번호     티켓가격  선실번호 목적지
# ...

# %% [markdown]
# * 컬럼 추가하기
# * 변수명['컬럼명'] = value

# %%
df['가족수'] = df['형제자매수'] + df['부모자식수']

# %%
df
# Out:
#      승객번호  생존여부  선실등급                                                 이름  \
# 0       1     0     3                            Braund, Mr. Owen Harris
# 1       2     1     1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       3     1     3                             Heikkinen, Miss. Laina
# 3       4     1     1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       5     0     3                           Allen, Mr. William Henry
# ..    ...   ...   ...                                                ...
# 886   887     0     2                              Montvila, Rev. Juozas
# 887   888     1     1                       Graham, Miss. Margaret Edith
# 888   889     0     3           Johnston, Miss. Catherine Helen "Carrie"
# 889   890     1     1                              Behr, Mr. Karl Howell
# 890   891     0     3                                Dooley, Mr. Patrick
#
#          성별    나이  형제자매수  부모자식수              티켓번호     티켓가격  선실번호 목적지  가족수
# ...

# %% [markdown]
# * 컬럼 삭제하기
# * del df['컬럼명']
# * df.drop('컬럼명', axis=1, inplace=True)

# %%
df = df.drop('부모자식수', axis=1)
df
# Out:
#      승객번호  생존여부  선실등급                                                 이름  \
# 0       1     0     3                            Braund, Mr. Owen Harris
# 1       2     1     1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       3     1     3                             Heikkinen, Miss. Laina
# 3       4     1     1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       5     0     3                           Allen, Mr. William Henry
# ..    ...   ...   ...                                                ...
# 886   887     0     2                              Montvila, Rev. Juozas
# 887   888     1     1                       Graham, Miss. Margaret Edith
# 888   889     0     3           Johnston, Miss. Catherine Helen "Carrie"
# 889   890     1     1                              Behr, Mr. Karl Howell
# 890   891     0     3                                Dooley, Mr. Patrick
#
#          성별    나이  형제자매수              티켓번호     티켓가격  선실번호 목적지  가족수
# ...

# %%
df.drop(['이름','승객번호'], axis=1)
# Out:
#      생존여부  선실등급      성별    나이  형제자매수              티켓번호     티켓가격  선실번호 목적지  가족수
# 0       0     3    male  22.0      1         A/5 21171   7.2500   NaN   S    1
# 1       1     1  female  38.0      1          PC 17599  71.2833   C85   C    1
# 2       1     3  female  26.0      0  STON/O2. 3101282   7.9250   NaN   S    0
# 3       1     1  female  35.0      1            113803  53.1000  C123   S    1
# 4       0     3    male  35.0      0            373450   8.0500   NaN   S    0
# ..    ...   ...     ...   ...    ...               ...      ...   ...  ..  ...
# 886     0     2    male  27.0      0            211536  13.0000   NaN   S    0
# 887     1     1  female  19.0      0            112053  30.0000   B42   S    0
# 888     0     3  female   NaN      1        W./C. 6607  23.4500   NaN   S    3
# 889     1     1    male  26.0      0            111369  30.0000  C148   C    0
# 890     0     3    male  32.0      0            370376   7.7500   NaN   Q    0
#
# [891 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['승객번호', '생존여부', '선실등급', '이름', '성별', '나이', '형제자매수', '티켓번호', '티켓가격',
#        '선실번호', '목적지', '가족수'],
#       dtype='object')

# %%
drop_cols = ['승객번호', '이름', '티켓번호', '티켓가격',
       '선실번호', '목적지', '가족수']

# %%
# 한번에 열 드롭 가능
df.drop(drop_cols, axis=1)
# Out:
#      생존여부  선실등급      성별    나이  형제자매수
# 0       0     3    male  22.0      1
# 1       1     1  female  38.0      1
# 2       1     3  female  26.0      0
# 3       1     1  female  35.0      1
# 4       0     3    male  35.0      0
# ..    ...   ...     ...   ...    ...
# 886     0     2    male  27.0      0
# 887     1     1  female  19.0      0
# 888     0     3  female   NaN      1
# 889     1     1    male  26.0      0
# 890     0     3    male  32.0      0
#
# [891 rows x 5 columns]

# %% [markdown]
# * 데이터 타입 바꾸기
# * astype(자료형)
# * apply(형변환함수)

# %%
df['승객번호'].astype('str')      # object = str
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: 승객번호, Length: 891, dtype: object

# %%
df['승객번호'].apply(str)
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: 승객번호, Length: 891, dtype: object

# %%
df['승객번호'] = df['승객번호'].apply(lambda x: '짝수' if float(x) % 2 ==0 else '홀수')
df
# Out:
#     승객번호  생존여부  선실등급                                                 이름  \
# 0     홀수     0     3                            Braund, Mr. Owen Harris
# 1     짝수     1     1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2     홀수     1     3                             Heikkinen, Miss. Laina
# 3     짝수     1     1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4     홀수     0     3                           Allen, Mr. William Henry
# ..   ...   ...   ...                                                ...
# 886   홀수     0     2                              Montvila, Rev. Juozas
# 887   짝수     1     1                       Graham, Miss. Margaret Edith
# 888   홀수     0     3           Johnston, Miss. Catherine Helen "Carrie"
# 889   짝수     1     1                              Behr, Mr. Karl Howell
# 890   홀수     0     3                                Dooley, Mr. Patrick
#
#          성별    나이  형제자매수              티켓번호     티켓가격  선실번호 목적지  가족수
# ...

# %% [markdown]
# # 판다스 데이터프레임에서 조건에 맞는 행만 가져오기
# * df[df['컬럼명'] 조건식]
# * 조건식 연산자 <, <=, >, >=, ==, !=, &, |

# %%
df[df['승객번호'] == '홀수']
# Out:
#     승객번호  생존여부  선실등급                                                 이름  \
# 0     홀수     0     3                            Braund, Mr. Owen Harris
# 2     홀수     1     3                             Heikkinen, Miss. Laina
# 4     홀수     0     3                           Allen, Mr. William Henry
# 6     홀수     0     1                            McCarthy, Mr. Timothy J
# 8     홀수     1     3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# ..   ...   ...   ...                                                ...
# 882   홀수     0     3                       Dahlberg, Miss. Gerda Ulrika
# 884   홀수     0     3                             Sutehall, Mr. Henry Jr
# 886   홀수     0     2                              Montvila, Rev. Juozas
# 888   홀수     0     3           Johnston, Miss. Catherine Helen "Carrie"
# 890   홀수     0     3                                Dooley, Mr. Patrick
#
#          성별    나이  형제자매수              티켓번호     티켓가격 선실번호 목적지  가족수
# ...

# %%
# 나이가 35 초과인 사람만 필터링
df[df['나이'] > 35]
# Out:
#     승객번호  생존여부  선실등급                                                 이름  \
# 1     짝수     1     1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 6     홀수     0     1                            McCarthy, Mr. Timothy J
# 11    짝수     1     1                           Bonnell, Miss. Elizabeth
# 13    짝수     0     3                        Andersson, Mr. Anders Johan
# 15    짝수     1     2                   Hewlett, Mrs. (Mary D Kingcome)
# ..   ...   ...   ...                                                ...
# 865   짝수     1     2                           Bystrom, Mrs. (Karolina)
# 871   짝수     1     1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 873   짝수     0     3                        Vander Cruyssen, Mr. Victor
# 879   짝수     1     1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 885   짝수     0     3               Rice, Mrs. William (Margaret Norton)
#
#          성별    나이  형제자매수      티켓번호     티켓가격  선실번호 목적지  가족수
# ...

# %% [markdown]
# * 여성이면서 나이가 35세 초과인 행 찾기

# %%
df[(df['성별'] == 'female') & (df['나이'] > 35)]
# Out:
#     승객번호  생존여부  선실등급                                                 이름  \
# 1     짝수     1     1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 11    짝수     1     1                           Bonnell, Miss. Elizabeth
# 15    짝수     1     2                   Hewlett, Mrs. (Mary D Kingcome)
# 25    짝수     1     3  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 40    홀수     0     3     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)
# ..   ...   ...   ...                                                ...
# 862   홀수     1     1  Swift, Mrs. Frederick Joel (Margaret Welles Ba...
# 865   짝수     1     2                           Bystrom, Mrs. (Karolina)
# 871   짝수     1     1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 879   짝수     1     1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 885   짝수     0     3               Rice, Mrs. William (Margaret Norton)
#
#          성별    나이  형제자매수      티켓번호     티켓가격  선실번호 목적지  가족수
# ...

# %% [markdown]
# * 성별이 남성이고 선실등급 1, 생존여부 1인 사람 찾기

# %%
df[(df['성별']=='male') & (df['선실등급']==1) & (df['생존여부']==1)]
# Out:
#     승객번호  생존여부  선실등급                                             이름    성별  \
# 23    짝수     1     1                   Sloper, Mr. William Thompson  male
# 55    짝수     1     1                              Woolner, Mr. Hugh  male
# 97    짝수     1     1                Greenfield, Mr. William Bertram  male
# 187   짝수     1     1  Romaine, Mr. Charles Hallace ("Mr C Rolmane")  male
# 209   짝수     1     1                               Blank, Mr. Henry  male
# 224   홀수     1     1                   Hoyt, Mr. Frederick Maxfield  male
# 248   홀수     1     1                  Beckwith, Mr. Richard Leonard  male
# 298   홀수     1     1                          Saalfeld, Mr. Adolphe  male
# 305   짝수     1     1                 Allison, Master. Hudson Trevor  male
# 370   홀수     1     1                    Harder, Mr. George Achilles  male
# 390   홀수     1     1                     Carter, Mr. William Ernest  male
# 430   홀수     1     1      Bjornstrom-Steffansson, Mr. Mauritz Hakan  male
# ...

# %% [markdown]
# * 선실 등급별 승차권 금액의 최소, 최대, 평균 등 4분위수를 보고싶다.

# %%
# 선실 등급이 1등석인 사람들의 승차권 금액 통계량을 보고싶다.
df[df['선실등급']==1]['티켓가격'].describe()
# Out:
# count    216.000000
# mean      84.154687
# std       78.380373
# min        0.000000
# 25%       30.923950
# 50%       60.287500
# 75%       93.500000
# max      512.329200
# Name: 티켓가격, dtype: float64

# %%
df[df['티켓가격'] > 512]
# Out:
#     승객번호  생존여부  선실등급                                  이름      성별    나이  형제자매수  \
# 258   홀수     1     1                    Ward, Miss. Anna  female  35.0      0
# 679   짝수     1     1  Cardeza, Mr. Thomas Drake Martinez    male  36.0      0
# 737   짝수     1     1              Lesurer, Mr. Gustave J    male  35.0      0
#
#          티켓번호      티켓가격         선실번호 목적지  가족수
# 258  PC 17755  512.3292          NaN   C    0
# 679  PC 17755  512.3292  B51 B53 B55   C    1
# 737  PC 17755  512.3292         B101   C    0

# %% [markdown]
# # 조건에 맞는 행을 찾은 후 특정 컬럼만 조회하기

# %% [markdown]
# * 선실 등급이 1이거나 2이면서 생존한 여성 중에서 이름 컬럼만 보고 싶을 때

# %%
df[((df['선실등급'] == 1) | (df['선실등급'] == 2)) & (df['생존여부'] == 1) & (df['성별']=='female')]['이름']
# Out:
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 9                    Nasser, Mrs. Nicholas (Adele Achem)
# 11                              Bonnell, Miss. Elizabeth
# 15                      Hewlett, Mrs. (Mary D Kingcome)
#                              ...
# 871     Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 874                Abelson, Mrs. Samuel (Hannah Wizosky)
# 879        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 880         Shelley, Mrs. William (Imanita Parrish Hall)
# 887                         Graham, Miss. Margaret Edith
# Name: 이름, Length: 161, dtype: object

# %% [markdown]
# * 나이가 25세 미만이면서 생존자의 이름과 나이

# %%
df.loc[(df['나이']<25) & (df['생존여부']==1), ['이름','나이']]
# Out:
#                                            이름    나이
# 9         Nasser, Mrs. Nicholas (Adele Achem)  14.0
# 10            Sandstrom, Miss. Marguerite Rut   4.0
# 22                McGowan, Miss. Anna "Annie"  15.0
# 39                Nicola-Yarred, Miss. Jamila  14.0
# 43   Laroche, Miss. Simonne Marie Anne Andree   3.0
# ..                                        ...   ...
# 855                Aks, Mrs. Sam (Leah Rosen)  18.0
# 858     Baclini, Mrs. Solomon (Latifa Qurban)  24.0
# 869           Johnson, Master. Harold Theodor   4.0
# 875          Najib, Miss. Adele Kiamie "Jane"  15.0
# 887              Graham, Miss. Margaret Edith  19.0
#
# [118 rows x 2 columns]

# %%
df[(df['나이']<25) & (df['생존여부']==1)][['이름','나이']] # 이중 대괄호
# Out:
#                                            이름    나이
# 9         Nasser, Mrs. Nicholas (Adele Achem)  14.0
# 10            Sandstrom, Miss. Marguerite Rut   4.0
# 22                McGowan, Miss. Anna "Annie"  15.0
# 39                Nicola-Yarred, Miss. Jamila  14.0
# 43   Laroche, Miss. Simonne Marie Anne Andree   3.0
# ..                                        ...   ...
# 855                Aks, Mrs. Sam (Leah Rosen)  18.0
# 858     Baclini, Mrs. Solomon (Latifa Qurban)  24.0
# 869           Johnson, Master. Harold Theodor   4.0
# 875          Najib, Miss. Adele Kiamie "Jane"  15.0
# 887              Graham, Miss. Margaret Edith  19.0
#
# [118 rows x 2 columns]

# %% [markdown]
# .isin([조건1,조건2]) or 조건을 여러번 써야할때 간단히 표현

# %% [markdown]
# * 선실 등급을 1,2등인 사람을 추출

# %%
df[df['선실등급'].isin([1,2])]
# Out:
#     승객번호  생존여부  선실등급                                                 이름  \
# 1     짝수     1     1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3     짝수     1     1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 6     홀수     0     1                            McCarthy, Mr. Timothy J
# 9     짝수     1     2                Nasser, Mrs. Nicholas (Adele Achem)
# 11    짝수     1     1                           Bonnell, Miss. Elizabeth
# ..   ...   ...   ...                                                ...
# 880   홀수     1     2       Shelley, Mrs. William (Imanita Parrish Hall)
# 883   짝수     0     2                      Banfield, Mr. Frederick James
# 886   홀수     0     2                              Montvila, Rev. Juozas
# 887   짝수     1     1                       Graham, Miss. Margaret Edith
# 889   짝수     1     1                              Behr, Mr. Karl Howell
#
#          성별    나이  형제자매수              티켓번호     티켓가격  선실번호 목적지  가족수
# ...

# %% [markdown]
# # 특정 단어를 포함한 행 찾기
# * 이름에 Joseph가 들어간 사람 찾기
# * like %단어% - SQL
# * .str.contains("찾을 단어")

# %%
df[df['이름'].str.contains('Joseph')]
# Out:
#     승객번호  생존여부  선실등급                                                 이름  \
# 20    홀수     0     2                               Fynney, Mr. Joseph J
# 34    홀수     0     1                            Meyer, Mr. Edgar Joseph
# 95    짝수     0     3                        Shorney, Mr. Charles Joseph
# 140   홀수     0     3                      Boulos, Mrs. Joseph (Sultana)
# 145   짝수     0     2                       Nicholls, Mr. Joseph Charles
# 194   홀수     1     1          Brown, Mrs. James Joseph (Margaret Tobin)
# 375   짝수     1     1              Meyer, Mrs. Edgar Joseph (Leila Saks)
# 454   홀수     0     3                                Peduzzi, Mr. Joseph
# 532   홀수     0     3                               Elias, Mr. Joseph Jr
# 559   짝수     1     3       de Messemaeker, Mrs. Guillaume Joseph (Emma)
# 578   홀수     0     3                   Caram, Mrs. Joseph (Maria Elias)
# 589   짝수     0     3                                Murdlin, Mr. Joseph
# ...

# %% [markdown]
# * 승객 이름에서 () 없애기
# * 반복문과 / 리스트 표현식을 이용해 없애기
# * apply + lambda 함수를 이용해 없애기
# * .str 메서드 (.str은 반복문을 대신함)

# %% [markdown]
# * 반복문 이용하기

# %%
result = []

for name in df['이름'][:5]:
    result.append(name.replace("(","").replace(")",""))

df['이름'][:5] = result
df.head(5)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_37556\3053854200.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['이름'][:5] = result
#    승객번호  생존여부  선실등급                                                 이름  \
# 0     1     0     3                            Braund, Mr. Owen Harris
# 1     2     1     1  Cumings, Mrs. John Bradley Florence Briggs Thayer
# 2     3     1     3                             Heikkinen, Miss. Laina
# 3     4     1     1         Futrelle, Mrs. Jacques Heath Lily May Peel
# 4     5     0     3                           Allen, Mr. William Henry
#
#        성별    나이  형제자매수  부모자식수              티켓번호     티켓가격  선실번호 목적지
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN   S
# 1  female  38.0      1      0          PC 17599  71.2833   C85   C
# ...

# %% [markdown]
# * apply와 람다함수를 통해 정의하기

# %%
# 원래 있던 요소 = name -> 추후 name에 괄호가 사라진 형태로 apply 됨
df['이름'].apply(lambda name: name.replace("\"","").replace("\'",""))
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley Florence Briggs Thayer
# 2                                 Heikkinen, Miss. Laina
# 3             Futrelle, Mrs. Jacques Heath Lily May Peel
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888               Johnston, Miss. Catherine Helen Carrie
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: 이름, Length: 891, dtype: object

# %% [markdown]
# .str.replace를 활용해서 처리하기

# %%
df['이름'].str.replace("\"","").str.replace("\'","").str.replace(",","")
# Out:
# 0                                Braund Mr. Owen Harris
# 1      Cumings Mrs. John Bradley Florence Briggs Thayer
# 2                                 Heikkinen Miss. Laina
# 3             Futrelle Mrs. Jacques Heath Lily May Peel
# 4                               Allen Mr. William Henry
#                              ...
# 886                                Montvila Rev. Juozas
# 887                         Graham Miss. Margaret Edith
# 888               Johnston Miss. Catherine Helen Carrie
# 889                                Behr Mr. Karl Howell
# 890                                  Dooley Mr. Patrick
# Name: 이름, Length: 891, dtype: object

# %% [markdown]
# .str.문자열함수(upper, lower, split, join, strip)

# %%
df['성'] = df['이름'].apply(lambda x: x.split(",")[0])
df
# Out:
#      승객번호  생존여부  선실등급                                                 이름  \
# 0       1     0     3                            Braund, Mr. Owen Harris
# 1       2     1     1  Cumings, Mrs. John Bradley Florence Briggs Thayer
# 2       3     1     3                             Heikkinen, Miss. Laina
# 3       4     1     1         Futrelle, Mrs. Jacques Heath Lily May Peel
# 4       5     0     3                           Allen, Mr. William Henry
# ..    ...   ...   ...                                                ...
# 886   887     0     2                              Montvila, Rev. Juozas
# 887   888     1     1                       Graham, Miss. Margaret Edith
# 888   889     0     3           Johnston, Miss. Catherine Helen "Carrie"
# 889   890     1     1                              Behr, Mr. Karl Howell
# 890   891     0     3                                Dooley, Mr. Patrick
#
#          성별    나이  형제자매수  부모자식수              티켓번호     티켓가격  선실번호 목적지  \
# ...

# %%
df['이름'].str.split(',')
# Out:
# 0                             [Braund,  Mr. Owen Harris]
# 1      [Cumings,  Mrs. John Bradley Florence Briggs T...
# 2                              [Heikkinen,  Miss. Laina]
# 3          [Futrelle,  Mrs. Jacques Heath Lily May Peel]
# 4                            [Allen,  Mr. William Henry]
#                              ...
# 886                             [Montvila,  Rev. Juozas]
# 887                      [Graham,  Miss. Margaret Edith]
# 888          [Johnston,  Miss. Catherine Helen "Carrie"]
# 889                             [Behr,  Mr. Karl Howell]
# 890                               [Dooley,  Mr. Patrick]
# Name: 이름, Length: 891, dtype: object

# %% [markdown]
# # groupby
# * 특정 기준 컬럼 지정해서 다른 컬럼의 통계량 (평균, 최소, 최대)
# * df[['보고싶은 컬럼1','보고싶은컬럼2']].groupby('기준컬럼).집합함수(mean,max,min,median,count)

# %% [markdown]
# * 성별별 생존자 수

# %%
df.columns
# Out:
# Index(['승객번호', '생존여부', '선실등급', '이름', '성별', '나이', '형제자매수', '부모자식수', '티켓번호',
#        '티켓가격', '선실번호', '목적지', '성'],
#       dtype='object')

# %%
df[['성별','생존여부']].groupby('성별').value_counts()
# Out:
# 성별      생존여부
# female  1       233
#         0        81
# male    0       468
#         1       109
# Name: count, dtype: int64

# %%
# sort = True 개수에 따라 정렬, False 기본 정렬
df[['성별','생존여부']].groupby('성별').value_counts(sort=False)
# Out:
# 성별      생존여부
# female  0        81
#         1       233
# male    0       468
#         1       109
# Name: count, dtype: int64

# %%
df[['성별','생존여부']].groupby('성별').count()
# Out:
#         생존여부
# 성별
# female   314
# male     577

# %%
pd.DataFrame(df[['성별','생존여부']].groupby('성별').value_counts(sort=False))
# Out:
#              count
# 성별     생존여부
# female 0        81
#        1       233
# male   0       468
#        1       109

# %% [markdown]
# 선실 등급 별 생존자 수

# %%
df[['선실등급','생존여부']].groupby('선실등급').value_counts(sort=False)
# Out:
# 선실등급  생존여부
# 1     0        80
#       1       136
# 2     0        97
#       1        87
# 3     0       372
#       1       119
# Name: count, dtype: int64

# %% [markdown]
# 성별, 선실등급 별 생존자 수

# %%
pd.DataFrame(
    df[['성별','선실등급','생존여부']]
    .groupby(['성별','선실등급'])
    .value_counts(sort=False)
)
# Out:
#                   count
# 성별     선실등급 생존여부
# female 1    0         3
#             1        91
#        2    0         6
#             1        70
#        3    0        72
#             1        72
# male   1    0        77
#             1        45
#        2    0        91
#             1        17
#        3    0       300
#             1        47

# %% [markdown]
# 은행 고객 등급
# - 급여 통장 입금 여부, 액수
# - 적금, 예금 상품

# %% [markdown]
# - 성별에 따른 나이의 평균, 최소, 최대값

# %%
df[['성별','나이']].groupby('성별').mean()
# Out:
#                나이
# 성별
# female  27.915709
# male    30.726645

# %%
df[['성별','나이']].groupby('성별').max()
# Out:
#           나이
# 성별
# female  63.0
# male    80.0

# %%
df[['성별','나이']].groupby('성별').min()
# Out:
#           나이
# 성별
# female  0.75
# male    0.42

# %%
df[['성별','나이']].groupby('성별').describe()
# Out:
#            나이
#         count       mean        std   min   25%   50%   75%   max
# 성별
# female  261.0  27.915709  14.110146  0.75  18.0  27.0  37.0  63.0
# male    453.0  30.726645  14.678201  0.42  21.0  29.0  39.0  80.0

# %%
df[['성별','나이']].groupby('성별').agg(['min','max','mean'])
# Out:
#           나이
#          min   max       mean
# 성별
# female  0.75  63.0  27.915709
# male    0.42  80.0  30.726645

# %% [markdown]
# * 피벗테이블 pivot

# %%
df.pivot_table(values='생존여부', index='성별', columns='선실등급')
# Out:
# 선실등급           1         2         3
# 성별
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %% [markdown]
# isna() 결측값인지 아닌지 확인 -> True(1), False(0) -> sum(결측값 개수)

# %%
# 결측값 비율
df.isna().sum() / len(df)*100
# Out:
# 승객번호      0.000000
# 생존여부      0.000000
# 선실등급      0.000000
# 이름        0.000000
# 성별        0.000000
# 나이       19.865320
# 형제자매수     0.000000
# 부모자식수     0.000000
# 티켓번호      0.000000
# 티켓가격      0.000000
# 선실번호     77.104377
# 목적지       0.224467
# 성         0.000000
# dtype: float64

# %% [markdown]
# dropna() 결측값이 있는 행을 모두 삭제

# %%
df.dropna()
# Out:
#      승객번호  생존여부  선실등급                                                 이름  \
# 1       2     1     1  Cumings, Mrs. John Bradley Florence Briggs Thayer
# 3       4     1     1         Futrelle, Mrs. Jacques Heath Lily May Peel
# 6       7     0     1                            McCarthy, Mr. Timothy J
# 10     11     1     3                    Sandstrom, Miss. Marguerite Rut
# 11     12     1     1                           Bonnell, Miss. Elizabeth
# ..    ...   ...   ...                                                ...
# 871   872     1     1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 872   873     0     1                           Carlsson, Mr. Frans Olof
# 879   880     1     1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 887   888     1     1                       Graham, Miss. Margaret Edith
# 889   890     1     1                              Behr, Mr. Karl Howell
#
#          성별    나이  형제자매수  부모자식수      티켓번호     티켓가격         선실번호 목적지          성
# ...

# %% [markdown]
# fillna() 결측값을 다른 값으로 채워주는 함수

# %%
df['나이'].isna().sum()
# Out:
# np.int64(177)

# %%
# 결측치가 다 사라짐
m = df['나이'].mean()
df['나이'] = df['나이'].fillna(m)
df['나이'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # 여러개의 데이터프레임 합치기
# * concat : 2개의 데이터프레임을 1개로 합침
# * merge : sql join과 같은 역할 공통된 기준컬럼 매칭해서 합침
# * join : sql join과 같은 역할 index가 같은 것끼리 합침

# %%
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb
# Out:
# <function pymysql.install_as_MySQLdb()>

# %%
engine = create_engine("mysql+pymysql://kict10:kict10@221.155.18.165:3306/titanic")
conn = engine.connect()

# %%
passenger = pd.read_sql("p_info", con=conn)
ticket = pd.read_sql("t_info", con=conn)
survived = pd.read_sql("survived", con=conn)
conn.close()

# %%
passenger.head(1)
# Out:
#    PassengerId                     Name   Sex   Age  SibSp  Parch
# 0            1  Braund, Mr. Owen Harris  male  22.0      1      0

# %%
ticket.head(1)
# Out:
#    PassengerId     Ticket  Pclass  Fare Cabin Embarked
# 0            1  A/5 21171       3  7.25  None        S

# %% [markdown]
# ## concat axis=0 행 추가, axis=1 열 추가
# * 기준 컬럼 없이 무조건 합침
# * 기본값은 행 방향으로 합쳐줌
# * 옆으로 붙이고 싶으면 axis=1

# %%
df_0 = pd.concat([passenger,ticket,survived],axis=0)
df_0.iloc[890:893,:]
# Out:
#      PassengerId                 Name   Sex   Age  SibSp  Parch     Ticket  \
# 890          891  Dooley, Mr. Patrick  male  32.0    0.0    0.0        NaN
# 0              1                  NaN   NaN   NaN    NaN    NaN  A/5 21171
# 1              2                  NaN   NaN   NaN    NaN    NaN   PC 17599
#
#      Pclass     Fare Cabin Embarked  Survived
# 890     NaN      NaN   NaN      NaN       NaN
# 0       3.0   7.2500  None        S       NaN
# 1       1.0  71.2833   C85        C       NaN

# %%
df1 = pd.concat([passenger,ticket,survived], axis=1)
df1
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
# ...

# %%
print('passenger', passenger.shape)
print('ticket', ticket.shape)
print('survived', survived.shape)
# Out:
# passenger (891, 6)
# ticket (891, 6)
# survived (891, 2)

# %% [markdown]
# # merge: 특정 컬럼 기준으로 합칠 때 sql의 join과 동일

# %%
# select * from passenger left join ticket on passenger.passengerId = ticket.passenderId
joined_df = pd.merge(passenger, ticket, how='left', on='PassengerId')  # inner, right, left 가능

# %%
# survived까지 innerjoin 됨
joined_df = pd.merge(joined_df, survived, how='inner', on='PassengerId')
joined_df
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
# ...

# %% [markdown]
# # join : sql의 join과 같음, index명을 기준으로 합침

# %%
passenger = passenger.set_index("PassengerId")

# %%
ticket = ticket.set_index("PassengerId")

# %%
joined_df2 = passenger.join(ticket)

# %%
survived = survived.set_index('PassengerId')

# %%
joined_df2 = joined_df2.join(survived)

# %%
joined_df2
# Out:
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
# ...

# %%
joined_df2 = joined_df2.reset_index()

# %%
joined_df2
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
# ...

# %% [markdown]
# # 중복여부 확인 및 제거하기

# %%
toss = pd.read_csv("./data/viva_republica_toss.csv", index_col = 0)

# %%
toss.duplicated().sum()
# Out:
# np.int64(52052)

# %% [markdown]
# 중복 컬럼 삭제하지 drop_duplicates()

# %%
toss = toss.drop_duplicates()
toss
# Out:
#             사용자  별점                                                 리뷰  \
# 0      Won Choi   2  토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...
# 1           최유연   1  증권부분이 너무 빈약해요. 이평선, 분봉, 틱봉 자유롭게 수치를 설정할 수 있었음 ...
# 2       EXPRESS   1  주식 UI에서 홈과 관심 종목을 나눈 것도 불편한데 이번 자주 사용하는 계좌 업데이...
# 3          JS P   1  언제 한 번 대대적으로 앱 퍼포먼스 최적화를 했으면 좋겠습니다. 예전엔 이러지 않았...
# 4      AndPeter   1  앱 최적화 좀 해주세요! 무슨 메모리를 1GB나 잡아먹고 패킷전송이 하루에 80만건...
# ...         ...  ..                                                ...
# 52560       나명자   5  사용은 편해요. 계좌개설 확인증이나 송금확인증 의 글씨가 좀 더 컸으면 좋겠습니다....
# 52561       김주영   4  소비 관리하는 데 아주 유용하게 쓰고 있습니다. ktx 예매 때문에 코레일을 이용했...
# 52562     bk im   1  편리함은 사라지고 불편함만 가중되고있음. 1. 동영상 광고 도입으로 토스 켤 때 마...
# 52563       임혜란   2  토스 편해서 사용했는데..최근에 토스에서 하는 꽃돼지이벤트 하다가 짜증났어요. 완전...
# 52564      60 2   3  왜 알람이 안 울릴까요? 입출금 알람 설정해뒀는데 어느 순간부터 안 울리네요 그렇다...
#
#                   날짜                                             개발자 응답
# ...

# %%
# 중복된 행 삭제 후 새로 인덱스 할당
toss = toss.reset_index(drop=True)
toss
# Out:
#           사용자  별점                                                 리뷰  \
# 0    Won Choi   2  토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...
# 1         최유연   1  증권부분이 너무 빈약해요. 이평선, 분봉, 틱봉 자유롭게 수치를 설정할 수 있었음 ...
# 2     EXPRESS   1  주식 UI에서 홈과 관심 종목을 나눈 것도 불편한데 이번 자주 사용하는 계좌 업데이...
# 3        JS P   1  언제 한 번 대대적으로 앱 퍼포먼스 최적화를 했으면 좋겠습니다. 예전엔 이러지 않았...
# 4    AndPeter   1  앱 최적화 좀 해주세요! 무슨 메모리를 1GB나 잡아먹고 패킷전송이 하루에 80만건...
# ..        ...  ..                                                ...
# 508       나명자   5  사용은 편해요. 계좌개설 확인증이나 송금확인증 의 글씨가 좀 더 컸으면 좋겠습니다....
# 509       김주영   4  소비 관리하는 데 아주 유용하게 쓰고 있습니다. ktx 예매 때문에 코레일을 이용했...
# 510     bk im   1  편리함은 사라지고 불편함만 가중되고있음. 1. 동영상 광고 도입으로 토스 켤 때 마...
# 511       임혜란   2  토스 편해서 사용했는데..최근에 토스에서 하는 꽃돼지이벤트 하다가 짜증났어요. 완전...
# 512      60 2   3  왜 알람이 안 울릴까요? 입출금 알람 설정해뒀는데 어느 순간부터 안 울리네요 그렇다...
#
#                 날짜                                             개발자 응답
# ...
