# %%
import requests
import pandas as pd
import json

store_dic = {}
i = 1

while i <= 43:
    url = "http://apis.data.go.kr/B553077/api/open/sdsc2/storeListInUpjong"
    payload = {'servicekey' : "lwJZpRMDn/p4YZe0Hzrf92CTBVmSbWToaTJgutxn3oJ6kss3RSoaZtwPvQiQLKYowcKSOnj3h6G54NvRysgQGA==", 
               'divId': 'indsSclsCd', 
               'key': 'I21006', 
               'numOfRows' : 1000, 
               'pageNo' : i,
               'type': 'json'}  

    r = requests.get(url, params=payload)

    data = r.json()

    for item in data['body']['items']:
        for key, value in zip(data['header']['columns'],item.values()):
            store_dic.setdefault(key,[]).append(value)
    
    i += 1
        
        
store_df = pd.DataFrame(store_dic)
store_df.to_csv("store_list")

# %%
import requests, urllib.parse

svc_key_raw = "lwJZpRMDn/p4YZe0Hzrf92CTBVmSbWToaTJgutxn3oJ6kss3RSoaZtwPvQiQLKYowcKSOnj3h6G54NvRysgQGA=="          # 2015년 이전 키는 UTF-8 URL 인코딩 필요
svc_key = urllib.parse.quote(svc_key_raw, safe='')  

url = "http://apis.data.go.kr/B551011/TarRlteTarService1/areaBasedList1"
params = {
    "serviceKey": svc_key,
    "numOfRows": 1000,
    "pageNo": 1,
    "MobileOS": "ETC",
    "MobileApp": "TestApp",
    "_type": "json",          # ← JSON 응답 지정!
    "baseYm": "202504",
    "areaCd": "51",
    "signguCd": "51130"
}

resp = requests.get(url, params=params, timeout=10)
resp.raise_for_status()       # 4xx/5xx 시 바로 예외

data = resp.json()            # 이제 정상 파싱
print(data["response"]["body"]["items"])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
# ...

# %%
print(resp.status_code)      # 200이어도 XML 오류일 수 있음
print(resp.headers['Content-Type'])
print(resp.text[:500])       # 앞 500자 확인
# Out:
# 200
# text/xml;charset=UTF-8
# <OpenAPI_ServiceResponse>
# 	<cmmMsgHeader>
# 		<errMsg>SERVICE ERROR</errMsg>
# 		<returnAuthMsg>SERVICE_KEY_IS_NOT_REGISTERED_ERROR</returnAuthMsg>
# 		<returnReasonCode>30</returnReasonCode>
# 	</cmmMsgHeader>
# </OpenAPI_ServiceResponse>
