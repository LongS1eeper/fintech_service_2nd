# %%
import pandas as pd

df = pd.read_stata("./data/PSIDSHELF_1968_2021_WIDE.dta")
df
# Out:
#             ID  LINEAGE  PNUM  FUID_1968  FUID_1969  FUID_1970  FUID_1971  \
# 0         1001        1     1        1.0     1597.0        NaN        NaN
# 1         1002        1     2        1.0     1597.0     1331.0      108.0
# 2         1003        1     3        1.0     1964.0      837.0      109.0
# 3         1004        1     4        1.0     1964.0      837.0      109.0
# 4         1030        1    30        NaN        NaN        NaN        NaN
# ...        ...      ...   ...        ...        ...        ...        ...
# 84116  9308001     9308     1        NaN        NaN        NaN        NaN
# 84117  9308002     9308     2        NaN        NaN        NaN        NaN
# 84118  9308003     9308     3        NaN        NaN        NaN        NaN
# 84119  9308004     9308     4        NaN        NaN        NaN        NaN
# 84120  9308170     9308   170        NaN        NaN        NaN        NaN
#
#        FUID_1972  FUID_1973  FUID_1974  ...  REL_MAR7_MYEAR  REL_MAR7_SYEAR  \
# ...

# %%
df.describe()
# Out:
#                  ID       LINEAGE          PNUM     FUID_1968     FUID_1969  \
# count  8.412100e+04  84121.000000  84121.000000  18192.000000  16862.000000
# mean   4.176948e+06   4176.866217     81.625991   3631.890391   2206.229392
# std    2.584166e+06   2584.176585     81.487894   2335.699954   1306.610924
# min    1.001000e+03      1.000000      1.000000      1.000000      1.000000
# 25%    1.800003e+06   1800.000000      4.000000   1438.000000   1042.250000
# 50%    5.018042e+06   5018.000000     36.000000   2824.000000   2218.000000
# 75%    6.215172e+06   6215.000000    173.000000   5895.000000   3343.750000
# max    9.308170e+06   9308.000000    294.000000   6872.000000   4460.000000
#
#           FUID_1970     FUID_1971     FUID_1972     FUID_1973     FUID_1974  \
# count  16978.000000  17252.000000  17628.000000  17777.000000  17988.000000
# mean    2343.495465   2468.307790   2562.465396   2642.762165   2800.353569
# ...

# %%
df.columns
# Out:
# Index(['ID', 'LINEAGE', 'PNUM', 'FUID_1968', 'FUID_1969', 'FUID_1970',
#        'FUID_1971', 'FUID_1972', 'FUID_1973', 'FUID_1974',
#        ...
#        'REL_MAR7_MYEAR', 'REL_MAR7_SYEAR', 'REL_MAR7_DYEAR', 'REL_MAR8_ID',
#        'REL_MAR8_MYEAR', 'REL_MAR8_SYEAR', 'REL_MAR8_DYEAR', 'PSID_RETRIEVE',
#        'PSIDSHELF_COMPILE', 'PSIDSHELF_RELEASE'],
#       dtype='object', length=7525)

# %%
import pandas as pd

df2 = pd.read_stata("./data/PSID_COMPLETE_MAIN_STUDY_1968_2021_ABRIDGED.dta")
df2
# Out:
#               ID  ER30001  ER30002  ER30003  ER30004  ER30010  ER30018  \
# 0         1001.0        1        1        1       52        8        0
# 1         1002.0        1        2        2       46        8        0
# 2         1003.0        1        3        7       21       12        0
# 3         1004.0        1        4        3       19       12        0
# 4         1030.0        1       30        0        0        0       97
# ...          ...      ...      ...      ...      ...      ...      ...
# 84116  9308001.0     9308        1        0        0        0       97
# 84117  9308002.0     9308        2        0        0        0       97
# 84118  9308003.0     9308        3        0        0        0       97
# 84119  9308004.0     9308        4        0        0        0       97
# 84120  9308170.0     9308      170        0        0        0       97
#
#        ER30019  ER30020  ER30021  ...  PID35  PID36  PID37  PID38  PID39  \
# ...

# %%
df2.columns
# Out:
# Index(['ID', 'ER30001', 'ER30002', 'ER30003', 'ER30004', 'ER30010', 'ER30018',
#        'ER30019', 'ER30020', 'ER30021',
#        ...
#        'PID35', 'PID36', 'PID37', 'PID38', 'PID39', 'PID40', 'PSID_RETRIEVE',
#        'PSIDCMS_COMPILE', 'PSIDCMS_DATA_TYPE', 'PSIDCMS_RELEASE'],
#       dtype='object', length=9182)

# %%
import pandas as pd

# 컬럼 표시 제한 해제
pd.set_option('display.max_columns', None)   # None = 무제한
pd.set_option('display.expand_frame_repr', False)  # 줄바꿈 없이 가로로 길게

# 이제 df 또는 df.columns 를 출력하면 7,525개 컬럼 전부가 보입니다
df2.head()          # 데이터 미리보기
df2.columns.tolist()  # 컬럼명만 리스트로
# Out:
# ['ID',
#  'ER30001',
#  'ER30002',
#  'ER30003',
#  'ER30004',
#  'ER30010',
#  'ER30018',
#  'ER30019',
#  'ER30020',
#  'ER30021',
#  'ER30022',
#  'ER30023',
#  'ER30031',
#  'ER30041',
#  'ER30042',
#  'ER30043',
#  'ER30044',
#  'ER30045',
#  'ER30046',
#  'ER30052',
#  'ER30055',
#  'ER30065',
#  'ER30066',
#  'ER30067',
#  'ER30068',
#  'ER30069',
#  'ER30070',
#  'ER30076',
#  'ER30079',
#  'ER30089',
#  'ER30090',
#  'ER30091',
#  'ER30092',
#  'ER30093',
#  'ER30094',
#  'ER30100',
#  'ER30104',
#  'ER30115',
#  'ER30116',
#  'ER30117',
#  'ER30118',
#  'ER30119',
#  'ER30120',
#  'ER30126',
#  'ER30128',
#  'ER30136',
#  'ER30137',
#  'ER30138',
#  'ER30139',
#  'ER30140',
#  'ER30141',
#  'ER30147',
#  'ER30149',
#  'ER30158',
#  'ER30159',
#  'ER30160',
#  'ER30161',
#  'ER30162',
#  'ER30163',
#  'ER30169',
#  'ER30170',
#  'ER30186',
#  'ER30187',
#  'ER30188',
#  'ER30189',
#  'ER30190',
#  'ER30191',
#  'ER30197',
#  'ER30200',
#  'ER30215',
#  'ER30216',
# ...
